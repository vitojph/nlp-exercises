# %% [markdown]
# # Analyzing a Twitter Collection
#
# The goal of the notebook is to leverage pre-trained NLP models and tools (eg. [textblob](https://textblob.readthedocs.io/en/dev/), [flair](https://github.com/flairNLP/flair), [spaCy](https://spacy.io/), [transformers pipelines](https://github.com/huggingface/transformers#quick-tour-of-pipelines), etc) to analyze real world natural language texts in English of two different varieties: on one hand, Twitter messages, supposed to contain informal samples of language; on the other hand, journal headlines, supposed to show formal uses of language.
#
# It's an open goal exercise, but there are some tasks you can attempt:
#
# - extract named entities
# - extract noun chunks
# - identify qualities of entities and actions
# - analyze sentiments of texts
# - associate sentiment and named entities
# - extract facts: WHAT happened? WHO did WHAT to WHOM?

# %%
# !pip install simpletransformers
# Out:
# Collecting simpletransformers
#   Downloading https://files.pythonhosted.org/packages/f4/41/418b2e4ffad5f165079a2ab4ec0be6cec4ff48bbddd2193c334b3f2a77db/simpletransformers-0.21.3-py3-none-any.whl (133kB)
#      |████████████████████████████████| 133kB 53.0MB/s
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/13/33/ffb67897a6985a7b7d8e5e7878c3628678f553634bd3836404fef06ef19b/transformers-2.5.1-py3-none-any.whl (499kB)
#      |████████████████████████████████| 501kB 56.8MB/s
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from simpletransformers) (1.4.1)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from simpletransformers) (4.28.1)
# Requirement already satisfied: regex in /usr/local/lib/python3.6/dist-packages (from simpletransformers) (2019.12.20)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from simpletransformers) (0.22.1)
# Collecting tensorboardx
#   Downloading https://files.pythonhosted.org/packages/35/f1/5843425495765c8c2dd0784a851a93ef204d314fc87bcc2bbb9f662a3ad1/tensorboardX-2.0-py2.py3-none-any.whl (195kB)
#      |████████████████████████████████| 204kB 69.6MB/s
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from simpletransformers) (1.17.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from simpletransformers) (2.21.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from simpletransformers) (0.25.3)
# Collecting seqeval
#   Downloading https://files.pythonhosted.org/packages/34/91/068aca8d60ce56dd9ba4506850e876aba5e66a6f2f29aa223224b50df0de/seqeval-0.0.12.tar.gz
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers->simpletransformers) (3.0.12)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/a6/b4/7a41d630547a4afd58143597d5a49e07bfd4c42914d8335b2a5657efc14b/sacremoses-0.0.38.tar.gz (860kB)
#      |████████████████████████████████| 870kB 62.2MB/s
# Collecting sentencepiece
#   Downloading https://files.pythonhosted.org/packages/74/f4/2d5214cbf13d06e7cb2c20d84115ca25b53ea76fa1f0ade0e3c9749de214/sentencepiece-0.1.85-cp36-cp36m-manylinux1_x86_64.whl (1.0MB)
#      |████████████████████████████████| 1.0MB 62.6MB/s
# Requirement already satisfied: boto3 in /usr/local/lib/python3.6/dist-packages (from transformers->simpletransformers) (1.11.15)
# Collecting tokenizers==0.5.2
#   Downloading https://files.pythonhosted.org/packages/d1/3f/73c881ea4723e43c1e9acf317cf407fab3a278daab3a69c98dcac511c04f/tokenizers-0.5.2-cp36-cp36m-manylinux1_x86_64.whl (3.7MB)
#      |████████████████████████████████| 3.7MB 58.3MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->simpletransformers) (0.14.1)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardx->simpletransformers) (3.10.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardx->simpletransformers) (1.12.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->simpletransformers) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->simpletransformers) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->simpletransformers) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->simpletransformers) (2019.11.28)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from pandas->simpletransformers) (2.6.1)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->simpletransformers) (2018.9)
# Requirement already satisfied: Keras>=2.2.4 in /usr/local/lib/python3.6/dist-packages (from seqeval->simpletransformers) (2.2.5)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers->simpletransformers) (7.0)
# Requirement already satisfied: botocore<1.15.0,>=1.14.15 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers->simpletransformers) (1.14.15)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers->simpletransformers) (0.3.3)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /usr/local/lib/python3.6/dist-packages (from boto3->transformers->simpletransformers) (0.9.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorboardx->simpletransformers) (45.2.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval->simpletransformers) (2.8.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval->simpletransformers) (1.1.0)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval->simpletransformers) (1.0.8)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from Keras>=2.2.4->seqeval->simpletransformers) (3.13)
# Requirement already satisfied: docutils<0.16,>=0.10 in /usr/local/lib/python3.6/dist-packages (from botocore<1.15.0,>=1.14.15->boto3->transformers->simpletransformers) (0.15.2)
# Building wheels for collected packages: seqeval, sacremoses
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-0.0.12-cp36-none-any.whl size=7424 sha256=e5073124feed26790663e97b834a9db1a82e3343ed6dc2ae5c73c76ec21b9269
#   Stored in directory: /root/.cache/pip/wheels/4f/32/0a/df3b340a82583566975377d65e724895b3fad101a3fb729f68
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.38-cp36-none-any.whl size=884628 sha256=201145a4ab7d5749731df97c137e3b75742bd1fffc93369b4b24e06282e181b5
#   Stored in directory: /root/.cache/pip/wheels/6d/ec/1a/21b8912e35e02741306f35f66c785f3afe94de754a0eaf1422
# Successfully built seqeval sacremoses
# Installing collected packages: sacremoses, sentencepiece, tokenizers, transformers, tensorboardx, seqeval, simpletransformers
# Successfully installed sacremoses-0.0.38 sentencepiece-0.1.85 seqeval-0.0.12 simpletransformers-0.21.3 tensorboardx-2.0 tokenizers-0.5.2 transformers-2.5.1

# %%
# !pip install spacy
# !python -m spacy download en
# Out:
# Requirement already satisfied: spacy in /usr/local/lib/python3.6/dist-packages (2.1.9)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.21.0)
# Requirement already satisfied: plac<1.0.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.9.6)
# Requirement already satisfied: blis<0.3.0,>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.2.4)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.17.5)
# Requirement already satisfied: thinc<7.1.0,>=7.0.8 in /usr/local/lib/python3.6/dist-packages (from spacy) (7.0.8)
# Requirement already satisfied: srsly<1.1.0,>=0.0.6 in /usr/local/lib/python3.6/dist-packages (from spacy) (1.0.1)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from spacy) (0.6.0)
# Requirement already satisfied: preshed<2.1.0,>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from spacy) (2.0.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2019.11.28)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy) (2.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.6/dist-packages (from thinc<7.1.0,>=7.0.8->spacy) (4.28.1)
# Requirement already satisfied: en_core_web_sm==2.1.0 from https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.1.0/en_core_web_sm-2.1.0.tar.gz#egg=en_core_web_sm==2.1.0 in /usr/local/lib/python3.6/dist-packages (2.1.0)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
# !git clone https://github.com/vitojph/nlp-exercises.git
# Out:
# Cloning into 'nlp-exercises'...
# remote: Enumerating objects: 3, done.
# remote: Counting objects: 100% (3/3), done.
# remote: Compressing objects: 100% (3/3), done.
# remote: Total 81 (delta 0), reused 2 (delta 0), pack-reused 78
# Unpacking objects: 100% (81/81), done.
# Checking out files: 100% (38/38), done.

# %%
# !pip install wandb
# Out:
# Collecting wandb
#   Downloading https://files.pythonhosted.org/packages/45/05/a0bf45b2f4909c3ffb1729deb19355a067a8cf8d56eebd3159d702321b68/wandb-0.8.29-py2.py3-none-any.whl (1.4MB)
#      |████████████████████████████████| 1.4MB 25.2MB/s
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: Click>=7.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (7.0)
# Collecting configparser>=3.8.1
#   Downloading https://files.pythonhosted.org/packages/7a/2a/95ed0501cf5d8709490b1d3a3f9b5cf340da6c433f896bbe9ce08dbe6785/configparser-4.0.2-py2.py3-none-any.whl
# Collecting gql==0.2.0
#   Downloading https://files.pythonhosted.org/packages/c4/6f/cf9a3056045518f06184e804bae89390eb706168349daa9dff8ac609962a/gql-0.2.0.tar.gz
# Collecting shortuuid>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/25/a6/2ecc1daa6a304e7f1b216f0896b26156b78e7c38e1211e9b798b4716c53d/shortuuid-1.0.1-py3-none-any.whl
# Collecting docker-pycreds>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/f5/e8/f6bd1eee09314e7e6dee49cbe2c5e22314ccdb38db16c9fc72d2fa80d054/docker_pycreds-0.4.0-py2.py3-none-any.whl
# Collecting GitPython>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/d3/2f/6a366d56c9b1355b0880be9ea66b166cb3536392638d8d91413ec66305ad/GitPython-3.1.0-py3-none-any.whl (450kB)
#      |████████████████████████████████| 460kB 61.0MB/s
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.6/dist-packages (from wandb) (2.6.1)
# Collecting watchdog>=0.8.3
#   Downloading https://files.pythonhosted.org/packages/73/c3/ed6d992006837e011baca89476a4bbffb0a91602432f73bd4473816c76e2/watchdog-0.10.2.tar.gz (95kB)
#      |████████████████████████████████| 102kB 16.7MB/s
# Collecting sentry-sdk>=0.4.0
#   Downloading https://files.pythonhosted.org/packages/8e/e6/058c2dc4723b3647a8cf61385c61f284bfbd0d0657bc5623c22e9ef45a3c/sentry_sdk-0.14.2-py2.py3-none-any.whl (96kB)
#      |████████████████████████████████| 102kB 17.6MB/s
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (7.352.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (2.21.0)
# Requirement already satisfied: PyYAML>=3.10 in /usr/local/lib/python3.6/dist-packages (from wandb) (3.13)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from wandb) (1.12.0)
# Collecting subprocess32>=3.5.3
#   Downloading https://files.pythonhosted.org/packages/32/c8/564be4d12629b912ea431f1a50eb8b3b9d00f1a0b1ceff17f266be190007/subprocess32-3.5.4.tar.gz (97kB)
#      |████████████████████████████████| 102kB 17.8MB/s
# Collecting graphql-core<2,>=0.5.0
#   Downloading https://files.pythonhosted.org/packages/b0/89/00ad5e07524d8c523b14d70c685e0299a8b0de6d0727e368c41b89b7ed0b/graphql-core-1.1.tar.gz (70kB)
#      |████████████████████████████████| 71kB 12.4MB/s
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.6/dist-packages (from gql==0.2.0->wandb) (2.3)
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/1e/f5/8f84b3bf9d94bdf2454a302f2fa375832b53660ea532586b8a55ff16ae9a/gitdb-4.0.2-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 4.9MB/s
# Collecting pathtools>=0.1.1
#   Downloading https://files.pythonhosted.org/packages/e7/7f/470d6fcdf23f9f3518f6b0b76be9df16dcc8630ad409947f8be2eb0ed13a/pathtools-0.1.2.tar.gz
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from sentry-sdk>=0.4.0->wandb) (2019.11.28)
# Requirement already satisfied: urllib3>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from sentry-sdk>=0.4.0->wandb) (1.24.3)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0.0->wandb) (3.0.4)
# Collecting smmap<4,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/35/d2/27777ab463cd44842c78305fa8097dfba0d94768abbb7e1c4d88f1fa1a0b/smmap-3.0.1-py2.py3-none-any.whl
# Building wheels for collected packages: gql, watchdog, subprocess32, graphql-core, pathtools
#   Building wheel for gql (setup.py) ... done
#   Created wheel for gql: filename=gql-0.2.0-cp36-none-any.whl size=7630 sha256=fae731cbbcaf8deb5116b43ed065a5c97284631173e011c752dc6f37174dff84
#   Stored in directory: /root/.cache/pip/wheels/ce/0e/7b/58a8a5268655b3ad74feef5aa97946f0addafb3cbb6bd2da23
#   Building wheel for watchdog (setup.py) ... done
#   Created wheel for watchdog: filename=watchdog-0.10.2-cp36-none-any.whl size=73605 sha256=cf200282bbc9115a68966c23a18954a3c49e29216e2f2fb26df1ecfd00a41564
#   Stored in directory: /root/.cache/pip/wheels/bc/ed/6c/028dea90d31b359cd2a7c8b0da4db80e41d24a59614154072e
#   Building wheel for subprocess32 (setup.py) ... done
#   Created wheel for subprocess32: filename=subprocess32-3.5.4-cp36-none-any.whl size=6489 sha256=ec1768ffae0504bd011b2bea6dbc5cd84de091ccdf31576e126642c036e739ed
#   Stored in directory: /root/.cache/pip/wheels/68/39/1a/5e402bdfdf004af1786c8b853fd92f8c4a04f22aad179654d1
#   Building wheel for graphql-core (setup.py) ... done
#   Created wheel for graphql-core: filename=graphql_core-1.1-cp36-none-any.whl size=104650 sha256=753e3b8cad49d0306527c301b15401ad0f9581c419524b24b05c68838f99b7ca
#   Stored in directory: /root/.cache/pip/wheels/45/99/d7/c424029bb0fe910c63b68dbf2aa20d3283d023042521bcd7d5
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-cp36-none-any.whl size=8784 sha256=3d3985d77b2cf89e7ab70d6508160f279ad91b66a7a559026e681b017a5a0339
#   Stored in directory: /root/.cache/pip/wheels/0b/04/79/c3b0c3a0266a3cb4376da31e5bfe8bba0c489246968a68e843
# Successfully built gql watchdog subprocess32 graphql-core pathtools
# Installing collected packages: configparser, graphql-core, gql, shortuuid, docker-pycreds, smmap, gitdb, GitPython, pathtools, watchdog, sentry-sdk, subprocess32, wandb
# Successfully installed GitPython-3.1.0 configparser-4.0.2 docker-pycreds-0.4.0 gitdb-4.0.2 gql-0.2.0 graphql-core-1.1 pathtools-0.1.2 sentry-sdk-0.14.2 shortuuid-1.0.1 smmap-3.0.1 subprocess32-3.5.4 wandb-0.8.29 watchdog-0.10.2

# %%
# !wandb login XXXXXXXXXXXXX
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Successfully logged in to Weights & Biases!

# %% [markdown]
# ## Twitter Messages

# %%
import numpy as np
import pandas as pd

# %%
tweets = pd.read_csv("/content/nlp-exercises/datasets/superbowl/tweets-superbowl.tsv", sep="\t", dtype=str)
tweets.head(10)
# Out:
#                                             tweet_id  ...                                               text
# 0                                 828319872929112064  ...  RT @BBCWorld: Astronauts attempt an out-of-thi...
# 1   https://t.co/bHxzttGXUR #SuperBowl2017 https://…  ...                                                NaN
# 2                                 828319872245432320  ...  RT @theoptionoracle: Retweet if you think the ...
# 3   #BoycottNFL #ladygaga #SuperBowl  Halftime Show.  ...                                                NaN
# 4                                    @AppSame #MAGA…  ...                                                NaN
# 5                                 828319872060944384  ...  RT @JODYHiGHROLLER: $100 FREE SUPERBOWL GiVE A...
# 6  $50 iN FREE DELiVERY OF ALL SNACKS &amp; ALCOH...  ...                                                NaN
# 7                            $50 iN FREE LYFT RiDES…  ...                                                NaN
# 8                                 828319872010563588  ...  RT @TheBaxterBean: TRUMP'S AMERIKKKA: Texas hi...
# 9                                 828319871784120321  ...  @DaRealWillPower are you ready for the superbo...
#
# [10 rows x 4 columns]

# %%
texts = [t for t in list(tweets["text"]) if isinstance(t, str)]
print(len(texts))
# Out:
# 49881

# %% [markdown]
# ## News Headlines
#
# AGNews is a collection of news categorized under 4 distinc categories:
#
# - World
# - Sports
# - Business
# - Sci/Tech
#
# Here, we're only interested in the text contents: the headline and the first paragraph.

# %%
news = pd.read_csv("/content/nlp-exercises/datasets/agnews/train.csv", dtype=str, header=None)
news.columns = "category headline text".split()
news.head(10)
# Out:
#   category  ...                                               text
# 0        3  ...  Reuters - Short-sellers, Wall Street's dwindli...
# 1        3  ...  Reuters - Private investment firm Carlyle Grou...
# 2        3  ...  Reuters - Soaring crude prices plus worries\ab...
# 3        3  ...  Reuters - Authorities have halted oil export\f...
# 4        3  ...  AFP - Tearaway world oil prices, toppling reco...
# 5        3  ...  Reuters - Stocks ended slightly higher on Frid...
# 6        3  ...  AP - Assets of the nation's retail money marke...
# 7        3  ...  USATODAY.com - Retail sales bounced back a bit...
# 8        3  ...  Forbes.com - After earning a PH.D. in Sociolog...
# 9        3  ...   NEW YORK (Reuters) - Short-sellers, Wall Stre...
#
# [10 rows x 3 columns]

# %%
import spacy

nlp = spacy.load("en")

doc = nlp("Donald Trump is the president. Donald Trump eats apples. Donald Trump gives a letter to her daughter.")

print([(ent.text, ent.label_) for ent in doc.ents])

print(list(doc.noun_chunks))

for sentence in doc.sents:
    who, action, what, whom = None, None, None, None
    for token in sentence:
        if token.dep_ == "ROOT":
            action = token.text
        elif token.dep_ == "nsubj":
            who = token.text
        elif token.dep_ == "dobj" or token.dep_ == "attr":
            what = token.text
        elif token.dep_ == "iobj":
            whom = token.text

    print(f"{who} -> {action} -> {what} -> {whom}")
# Out:
# [('Donald Trump', 'PERSON'), ('Donald Trump', 'PERSON'), ('Donald Trump', 'PERSON')]
# [Donald Trump, the president, Donald Trump, apples, Donald Trump, a letter, her daughter]
# Trump -> is -> president -> None
# Trump -> eats -> apples -> None
# Trump -> gives -> letter -> None

# %%
from collections import Counter
from tqdm import tqdm_notebook as tqdm

tweets_entities_counter = Counter()

for text in tqdm(texts):
    doc = nlp(text)
    tweets_entities_counter += Counter([f"{ent.text} {ent.label_}" for ent in doc.ents])

print(tweets_entities_counter)
# Out:
# HBox(children=(IntProgress(value=0, max=49881), HTML(value='')))
# Counter({'SuperBowl MONEY': 11466, 'SuperBowl ORG': 5149, '# CARDINAL': 3683, 'Superbowl PRODUCT': 2536, 'SuperBowl PRODUCT': 2171, 'first ORDINAL': 1507, '#SuperBowl # MONEY': 1497, 'Sunday DATE': 1387, 'Tom Brady PERSON': 1231, 'Patriots ORG': 1207, 'tonight TIME': 1190, 'today DATE': 1097, 'NFL ORG': 1096, 'Nick Foles PERSON': 778, '#SuperBowl MONEY': 713, 'Philadelphia GPE': 616, '#Eagles MONEY': 546, 'the Super Bowl EVENT': 543, 'Beyoncé PERSON': 512, 'Lady Gaga PERSON': 510, 'Eagles ORG': 506, 'Michael Jackson PERSON': 498, 'Brady PERSON': 469, 'HISTORY ORG': 445, '25 Years DATE': 440, 'Halftime Show WORK_OF_ART': 440, 'Bruno Mars PERSON': 428, 'Philadelphia Eagles ORG': 418, 'PepsiHalftime ORG': 410, 'Chris Long PERSON': 404, '2 years DATE': 401, '6 CARDINAL': 396, 'one CARDINAL': 362, 'last year DATE': 361, 'Superbowl MONEY': 338, 'America GPE': 323, '@Eagles GPE': 322, 'Trump ORG': 309, 'JustinTimberlake ORG': 296, 'Kevin Hart PERSON': 294, 'Superbowl ORG': 291, 'New England LOC': 262, 'Super Bowl EVENT': 260, 'Justin Timberlake PERSON': 258, 'Justin’s ORG': 252, 'Atlanta GPE': 240, 'Justin ORG': 231, 'RT GPE': 219, 'TD ORG': 217, 'Americans NORP': 213, 'this year DATE': 208, 'HalftimeShow ORG': 191, '2 CARDINAL': 190, 'half CARDINAL': 187, 'two CARDINAL': 187, 'tomorrow DATE': 185, 'Minneapolis GPE': 182, 'Today DATE': 181, '#superbowl # MONEY': 176, '#Superbowl # MONEY': 176, 'second ORDINAL': 175, 'next year DATE': 170, '2018 DATE': 168, 'sunday DATE': 166, 'Minnesota GPE': 166, '#FlyEaglesFly MONEY': 162, '@Patriots ORG': 159, 'RT ORG': 153, 'Dreams &amp ORG': 152, 'QB GPE': 146, '5 CARDINAL': 143, 'American NORP': 142, 'Mood ORG': 140, 'Janet Jackson PERSON': 138, '3 CARDINAL': 136, 'Chinese NORP': 136, '😭😭😭 PERSON': 136, 'the National Anthem ORG': 131, '2017 DATE': 131, "Lady Gaga's PERSON": 130, 'RT @Patriots ORG': 126, '👏 GPE': 126, 'One CARDINAL': 126, '#FlyEaglesFly # MONEY': 126, 'Nightmares NORP': 124, 'Putin PERSON': 122, 'SUPERBOWL ORG': 120, '@NFL ORG': 117, 'year DATE': 117, '@Patriots GPE': 112, '#SBLII # MONEY': 112, 'SB51 MONEY': 111, 'Bill PERSON': 109, '🏈 PERSON': 108, 'Kris Wu PERSON': 108, 'Rod Rosenstein PERSON': 108, '1 CARDINAL': 107, '#Su PERSON': 106, '5 years DATE': 106, 'Yeaaaa GPE': 106, '40-60 CARDINAL': 104, 'Two CARDINAL': 103, 'NBC ORG': 102, '2018-02-04 DATE': 102, 'Jack Pearson PERSON': 102, 'Kylie Jenner PERSON': 102, 'Eli ORG': 102, '#NFL MONEY': 99, 'Pats NORP': 97, 'First ORDINAL': 95, 'Rihanna ORG': 94, 'MAGA ORG': 91, 'Kylie PERSON': 90, '100 MONEY': 88, 'Houston GPE': 88, 'Odell ORG': 88, '#SuperBowl PERSON': 87, '#PepsiHalftime # MONEY': 86, '’s GPE': 84, 'Tide PRODUCT': 84, "Tom Brady's PERSON": 82, '10 CARDINAL': 82, '100 million # MONEY': 82, 'Eli Manning ORG': 80, 'US GPE': 79, '🇬🇧 PERSON': 76, 'Doug Pederson PERSON': 76, '😂 DATE': 74, 'Morgan Freeman PERSON': 74, 'RT @CNN ORG': 74, 'YUP ORG': 74, 'GOAT ORG': 73, 'the day DATE': 72, 'Champion ORG': 72, 'SBLII ORG': 72, 'Scottish NORP': 72, 'U.S. Bank Stadium ORG': 72, 'Bill Belichick PERSON': 71, 'INCREDIBLE ORG': 71, 'Tom PERSON': 70, 'RT @ScottPresler ORG': 70, 'JusticeforJanet ORG': 70, 'FlyEaglesFly MONEY': 70, 'Peter Dinklage PERSON': 70, 'Dodge ORG': 68, 'about some # MONEY': 66, '99 year old DATE': 66, '1918 DATE': 66, 'PATRIOTS ORG': 65, '@NFL GPE': 64, 'RT @ABC ORG': 64, '#Eagles # MONEY': 64, 'SuperbOwl MONEY': 62, '30-day DATE': 62, 'Ram PERSON': 62, 'Usher PERSON': 62, 'Despite Philadelphia Eagles ORG': 62, 'the Walking Dead ORG': 60, '4 CARDINAL': 59, 'MVP ORG': 59, 'Boston GPE': 58, '28 CARDINAL': 58, 'The Philadelphia Eagles ORG': 58, 'Martin Luther King Jr. PERSON': 58, 'Meek Mill ORG': 56, 'Gaga ORG': 55, 'Gronk GPE': 55, 'National Anthem ORG': 54, '@NFoles_9 PERSON': 54, '@Eagles PERSON': 54, 'Gaga PERSON': 53, 'Muslim NORP': 53, 'Donald Trump PERSON': 52, '#flyeaglesfly # MONEY': 52, 'Kris Jenner PERSON': 52, 'Champs ORG': 52, '#Superbowl MONEY': 51, '@Patriots &amp ORG': 51, '&amp ORG': 50, '#1 MONEY ...

# %%
news_entities_counter = Counter()

for text in tqdm(news["headline"]):
    doc = nlp(text)
    news_entities_counter += Counter([f"{ent.text} {ent.label_}" for ent in doc.ents])

print(news_entities_counter)
# Out:
# HBox(children=(IntProgress(value=0, max=120000), HTML(value='')))
# Counter({'AP ORG': 7405, 'Reuters ORG': 3835, 'US GPE': 3381, '39 MONEY': 2409, 'Microsoft ORG': 2017, 'Iraq GPE': 1872, 'AFP ORG': 1734, 'U.S. GPE': 1361, 'China GPE': 1276, 'IBM ORG': 1050, 'Bush PERSON': 900, 'India GPE': 853, 'Japan GPE': 823, 'EU ORG': 792, 'UN ORG': 702, 'Intel ORG': 658, '39;s MONEY': 630, 'Iran GPE': 599, '& ORG': 580, 'Russia GPE': 577, 'UK GPE': 540, '3 CARDINAL': 514, 'Pakistan GPE': 512, 'Israel GPE': 492, 'Iraqi NORP': 488, '1 CARDINAL': 482, '#39;s MONEY': 480, '2 CARDINAL': 469, 'first ORDINAL': 464, 'Australia GPE': 459, 'Google ORG': 457, 'Oracle ORG': 413, 'Canadian Press ORG': 405, 'Two CARDINAL': 401, 'Arafat PERSON': 398, 'Apple ORG': 391, 'Darfur GPE': 389, 'Israeli NORP': 382, 'British NORP': 380, 'NASA ORG': 379, 'Sony ORG': 374, 'PeopleSoft ORG': 371, 'Baghdad GPE': 364, 'Europe LOC': 326, 'Gaza GPE': 315, 'Afghan NORP': 305, 'France GPE': 301, 'Palestinian NORP': 292, 'SEC ORG': 290, 'Russian NORP': 289, 'two CARDINAL': 284, 'England GPE': 278, '2005 DATE': 273, 'French NORP': 272, 'NBA ORG': 271, 'Australian NORP': 264, 'Update1 ORG': 263, 'Palestinians NORP': 262, 'Chinese NORP': 257, 'Cisco GPE': 256, 'Sudan GPE': 254, '10 CARDINAL': 248, 'Britain GPE': 246, 'Canada GPE': 239, 'Indian NORP': 233, 'NewsFactor ORG': 233, '4 CARDINAL': 232, 'Florida GPE': 230, 'Tokyo GPE': 219, 'Three CARDINAL': 218, 'Japanese NORP': 210, 'UPDATE ORG': 208, 'Spain GPE': 203, 'NFL ORG': 200, 'Sun ORG': 198, 'Brazil GPE': 198, 'Afghanistan GPE': 196, 'European NORP': 195, 'Germany GPE': 195, 'AOL ORG': 192, 'GM ORG': 192, 'second ORDINAL': 186, 'Kerry PERSON': 186, 'Canadian NORP': 185, '5 CARDINAL': 185, 'Boeing ORG': 185, 'German NORP': 182, '2004 DATE': 180, 'Red Sox ORG': 174, 'Turkey GPE': 171, 'Fed ORG': 170, 'Giants ORG': 166, 'Indonesia GPE': 163, 'FDA ORG': 162, 'Taiwan GPE': 161, 'AMD ORG': 161, 'Egypt GPE': 158, 'Italy GPE': 157, '39;t MONEY': 157, 'Four CARDINAL': 153, 'Italian NORP': 153, 'Nokia ORG': 153, 'NHL ORG': 152, 'House ORG': 152, 'Linux ORG': 151, 'Americans NORP': 150, 'Texas GPE': 150, 'Ford ORG': 148, 'Putin PERSON': 148, 'Wal-Mart ORG': 145, 'Hamas ORG': 144, 'One CARDINAL': 143, 'Asian NORP': 140, 'United ORG': 137, 'Kashmir LOC': 136, 'Asia LOC': 135, 'Ziff Davis PERSON': 135, 'Irish NORP': 134, 'one CARDINAL': 133, 'HP ORG': 132, 'Update2 ORG': 132, 'OPEC ORG': 131, 'three CARDINAL': 131, '11 CARDINAL': 130, 'Airbus ORG': 130, 'August DATE': 127, 'California GPE': 126, 'Dutch NORP': 125, 'four CARDINAL': 125, '6 CARDINAL': 124, 'Enron ORG': 124, 'American NORP': 123, '7 CARDINAL': 123, 'Williams PERSON': 123, 'US Airways ORG': 121, '8 CARDINAL': 120, '12 CARDINAL': 120, 'Washington GPE': 120, '2006 DATE': 120, 'Fallujah GPE': 119, 'October DATE': 118, 'FCC ORG': 117, 'Sharon PERSON': 117, 'Ukraine GPE': 116, 'Paris GPE': 115, 'Miami GPE': 115, 'Boston GPE': 114, 'Senate ORG': 114, 'Yankees ORG': 113, 'Iraqis NORP': 111, 'Haiti GPE': 111, 'Linux GPE': 109, 'Merck ORG': 109, 'First ORDINAL': 108, 'Syria GPE': 108, 'Najaf GPE': 107, 'Singapore GPE': 107, 'September DATE': 107, 'Verizon GPE': 105, 'InfoWorld ORG': 105, 'Congress ORG': 104, 'Hollywood GPE': 104, 'Update3 ORG': 103, 'Blair ORG': 102, 'Samsung ORG': 102, '20 CARDINAL': 101, 'Karzai PERSON': 101, 'Novell ORG': 101, 'Indonesian NORP': 101, '13 CARDINAL': 100, 'London GPE': 99, 'Beijing GPE': 99, 'SPACE.com ORG': 98, 'Ivory Coast GPE': 98, 'Sunday DATE': 98, 'third ORDINAL': 97, 'Nintendo ORG': 97, 'November DATE': 97, 'North Korea GPE': 96, '100 CARDINAL': 96, 'New York GPE': 96, '17 CARDINAL': 95, 'Nigeria GPE': 95, 'Greek NORP': 93, 'Zimbabwe GPE': 93, 'Thailand GPE': 91, 'Greenspan PERSON': 91, 'Lebanon GPE': 91, 'AL ORG': 89, 'U.N. ORG': 89, 'Toshiba ORG': 89, 'Libya GPE': 89, 'WTO ORG': 89, 'Cuba GPE': 88, 'Six CARDINAL': 88, '# CARDINAL': 88, 'Kodak ORG': 88, 'Thai NORP': 88, 'Mexico GPE': 86, 'Philippines GPE': 86, 'Malaysia GPE': 86, 'Fannie Mae ORG': 86, 'Titan GPE': 85, 'five CARDINAL': 84, 'Mars LOC': 84, ...

# %%
from transformers import pipeline

sentiment_classifier = pipeline("sentiment-analysis")
ner = pipeline("ner")
# Out:
# HBox(children=(IntProgress(value=0, description='Downloading', max=230, style=ProgressStyle(description_width=…
# HBox(children=(IntProgress(value=0, description='Downloading', max=230, style=ProgressStyle(description_width=…

# %%
from collections import Counter
from tqdm import tqdm_notebook as tqdm

positives = Counter()
negatives = Counter()

for text in tqdm(news["text"][:1000]):
    sentiment = sentiment_classifier(text)[0]["label"]
    if sentiment == "POSITIVE":
        positives += Counter([item["word"] for item in ner(text)])
    else:
        negatives += Counter([item["word"] for item in ner(text)])
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))
# Counter({'##uters': 57, 'Re': 56, 'S': 36, '.': 34, 'U': 33, 'AP': 24, '##K': 21, 'Olympic': 21, 'K': 20, '##S': 19, 'of': 17, 'University': 17, 'Earth': 16, 'W': 16, 'Y': 15, '-': 15, '##OR': 14, 'American': 14, 'NASA': 14, 'Phelps': 13, 'NE': 12, '##W': 12, 'A': 12, 'Michael': 12, 'Championship': 12, '##o': 11, 'Inc': 11, 'Bush': 11, 'C': 11, '##N': 10, '##M': 10, 'Corp': 10, 'United': 10, '##D': 10, '##EN': 10, 'G': 9, 'N': 9, 'O': 9, 'P': 9, '##d': 9, 'Java': 9, 'PGA': 9, '##i': 8, 'New': 8, 'States': 8, 'F': 8, '##A': 8, 'Pro': 8, '##P': 8, 'John': 8, '##co': 8, '##sa': 7, 'National': 7, 'Health': 7, 'V': 7, 'Europe': 7, 'Per': 7, '##sei': 7, '##O': 7, 'Space': 7, 'Washington': 7, 'Iraq': 7, 'Microsoft': 7, 'J': 7, 'US': 7, '##vez': 7, 'Japan': 7, 'Greece': 7, '##is': 7, 'Ian': 7, 'Thorpe': 7, '##e': 7, 'Vijay': 7, 'Singh': 7, '##ar': 7, 'Venezuela': 7, 'T': 6, 'North': 6, 'X': 6, 'Open': 6, 'Ko': 6, '3D': 6, 'Athens': 6, 'The': 6, '##R': 6, 'Olympics': 6, 'Chandra': 6, 'E': 6, 'Do': 6, '##ay': 6, 'AT': 6, '##H': 6, '##f': 6, '##a': 6, 'Hugo': 6, 'Cha': 6, 'Di': 6, 'Google': 5, 'South': 5, 'Davis': 5, 'Asia': 5, 'B': 5, 'L': 5, 'British': 5, 'Station': 5, "'": 5, 's': 5, '##ran': 5, 'Hu': 5, 'M': 5, 'Ha': 5, 'Kerry': 5, '##G': 5, '##UN': 5, '##B': 5, '##LE': 5, 'Cut': 5, 'Wisconsin': 5, 'Central': 5, '##Z': 5, 'War': 5, '##y': 5, 'i': 5, '##Y': 5, 'TO': 5, '##U': 5, 'Japanese': 5, 'Pieter': 5, 'van': 5, 'den': 5, 'Ho': 5, '##ogen': 5, '##band': 5, 'Indians': 5, 'Twins': 5, 'Justin': 5, 'Leonard': 5, 'Hungarian': 5, 'Na': 5, 'Venezuelan': 5, 'Chris': 5, 'Ryder': 5, 'Cup': 5, 'Wall': 4, 'Street': 4, 'Asian': 4, 'International': 4, 'CA': 4, '##k': 4, '##ON': 4, 'He': 4, '##wl': 4, '##ett': 4, 'Packard': 4, 'Texas': 4, '##s': 4, 'Russian': 4, 'America': 4, '##ch': 4, '##L': 4, '##es': 4, 'Saturn': 4, 'the': 4, 'Saudi': 4, 'MS': 4, '##FT': 4, '##er': 4, 'Duke': 4, 'Z': 4, 'H': 4, 'Lu': 4, '##nine': 4, 'Arizona': 4, 'St': 4, '##c': 4, '##let': 4, 'Keller': 4, '##FP': 4, 'Cleveland': 4, 'Minnesota': 4, '##ko': 4, 'League': 4, 'Chicago': 4, '##histling': 4, 'Straits': 4, 'City': 4, '##rman': 4, 'Jay': 4, 'Haas': 4, 'Grand': 4, 'Prix': 4, 'World': 4, 'Baghdad': 4, '##ja': 4, '##ah': 4, '##OH': 4, 'Charley': 4, 'Willis': 4, 'Steve': 4, '##al': 4, 'African': 3, 'Bay': 3, 'Thailand': 3, '##EA': 3, 'Auto': 3, '##des': 3, 'Service': 3, 'SEC': 3, 'Prize': 3, 'Linux': 3, 'Pacific': 3, '##nos': 3, '##bble': 3, 'Tel': 3, '##cope': 3, '##no': 3, 'So': 3, 'al': 3, '##ma': 3, 'bin': 3, 'La': 3, '##den': 3, 'API': 3, 'Northern': 3, 'Virginia': 3, '##IS': 3, '##m': 3, 'Florida': 3, 'Center': 3, '##la': 3, 'Observatory': 3, '##man': 3, 'Titan': 3, 'Reporter': 3, 'HP': 3, 'SA': 3, '##l': 3, 'Apple': 3, 'In': 3, 'D': 3, '##RO': 3, 'Games': 3, 'Motion': 3, 'DVD': 3, 'Studio': 3, '3': 3, 'Louis': 3, '##ol': 3, 'Team': 3, 'Los': 3, 'Angeles': 3, 'Press': 3, 'Tour': 3, 'French': 3, 'Jones': 3, 'Atlanta': 3, 'Braves': 3, 'Sc': 3, '##AV': 3, 'San': 3, 'Francisco': 3, 'Andy': 3, 'Revolution': 3, 'Australia': 3, 'France': 3, 'Williams': 3, 'China': 3, 'Schumacher': 3, 'Afghanistan': 3, 'Afghan': 3, 'Lie': 3, '##chtenstein': 3, 'Shi': 3, '##ite': 3, '##RA': 3, 'Corey': 3, '##ski': 3, 'Donald': 3, 'Pan': 3, 'Riley': 3, '##ee': 3, '##AR': 3, 'Hal': 3, 'Mart': 3, '##te': 3, '##le': 2, 'Playboy': 2, 'Free': 2, 'Massachusetts': 2, 'Americans': 2, 'Chip': 2, 'Henry': 2, 'As': 2, 'Blues': 2, 'Philippines': 2, '##pan': 2, 'Mu': 2, '##MF': 2, 'Hong': 2, 'Kong': 2, 'Bangkok': 2, '##t': 2, 'Systems': 2, '##ner': 2, 'Sprint': 2, 'ST': 2, '##ic': 2, 'Tech': 2, 'News': 2, 'Nobel': 2, 'Pen': 2, '##cola': 2, 'Naval': 2, 'Air': 2, 'Columbia': 2, 'Valley': 2, 'Brazil': 2, 'Genesis': 2, 'Oregon': 2, 'State': 2, 'Anthony': 2, 'Ki': 2, '##rin': 2, '##ci': 2, 'DE': 2, '##AD': 2, 'Mars': 2, 'Ty': 2, 're': 2, 'Baltimore': 2, 'Cass': 2, '##ini': 2, '##sca': 2, 'CNN': 2, '##rb': 2, 'BA': 2, '##ya': 2, 'Iraqi': 2, 'Syria': 2, 'Scotland': 2, '##OS': 2, '&': 2, '##alo': 2, '##w': 2, ' ...
# Counter({'##uters': 124, 'Re': 121, 'S': 60, '.': 58, 'U': 52, 'Inc': 45, 'AP': 40, 'Google': 38, '##A': 37, '##s': 33, '##S': 32, 'N': 31, 'A': 30, '##K': 28, '##O': 27, '##W': 26, '-': 25, '&': 25, 'NE': 24, '##r': 24, 'Corp': 24, 'Microsoft': 24, 'Windows': 24, '##i': 23, 'K': 23, 'Y': 22, 'O': 21, '##P': 21, '##OR': 20, 'L': 20, 'Iraq': 19, 'Florida': 19, 'Olympic': 19, '##FP': 18, '##RA': 18, '##H': 17, 'J': 17, 'Internet': 17, 'Co': 17, 'Hugo': 17, 'Cha': 17, '##vez': 17, 'US': 16, 'Sudan': 16, 'F': 16, 'New': 16, 'C': 16, 'Venezuelan': 16, '##E': 15, 'I': 15, 'Charley': 15, 'San': 15, '##G': 15, 'Venezuela': 15, 'South': 14, 'John': 14, 'B': 14, 'United': 14, '##fu': 13, '##C': 13, '##n': 13, '##D': 13, '##T': 13, 'T': 12, 'P': 12, 'Dar': 12, 'The': 12, 'X': 12, 'MS': 12, 'CA': 12, '##N': 11, '##t': 11, 'Bush': 11, "'": 11, '##if': 11, '##er': 11, '##B': 11, 'HP': 11, '##CA': 11, 'com': 10, '##e': 10, 'National': 10, 'India': 10, '##o': 10, 'M': 10, '##ON': 10, 'SA': 10, 'GO': 10, '##ay': 9, 'French': 9, 'Japan': 9, 'Playboy': 9, 'Canadian': 9, 'Mo': 9, '##m': 9, 'l': 9, 'W': 9, 'Press': 9, '##AL': 9, 'China': 9, 'Olympics': 9, 'Athens': 9, 'Na': 9, '##I': 8, 'of': 8, 'American': 8, 'America': 8, '##es': 8, '##Y': 8, '##UN': 8, 'e': 8, 'States': 8, '##UR': 8, '##IC': 8, 'Paul': 8, '##f': 8, 'Iraqi': 8, 'Michael': 8, 'Games': 8, '##NT': 8, '##US': 8, 's': 8, 'IBM': 7, 'York': 7, 'G': 7, 'World': 7, 'British': 7, 'Australia': 7, 'Asia': 7, 'V': 7, 'Washington': 7, 'Linux': 7, 'Malaysia': 7, 'Ser': 7, '##a': 7, '##c': 7, '##ou': 7, 'Greece': 7, 'Red': 7, 'Sox': 7, '##EN': 7, 'Palestinian': 7, 'Israel': 7, 'Day': 7, '##ja': 7, 'Afghanistan': 7, 'AT': 7, 'Lowe': 7, '##mart': 7, 'Holding': 7, 'Saudi': 6, 'UK': 6, 'Si': 6, 'Gateway': 6, 'Russian': 6, 'Hu': 6, 'Tel': 6, 'University': 6, '##eri': 6, 'Americans': 6, 'Shi': 6, '##y': 6, 'St': 6, 'LA': 6, 'FCC': 6, '"': 6, 'Cal': 6, 'Greek': 6, 'Ka': 6, 'Israeli': 6, 'All': 6, 'Rwanda': 6, 'Arab': 6, '##ese': 6, 'Pope': 6, '##TA': 6, '##RD': 6, '##la': 6, 'Puerto': 6, 'Rico': 6, 'Phelps': 6, '##ER': 6, 'CH': 6, '##AG': 6, '##MR': 6, 'Dell': 5, 'Iran': 5, 'Japanese': 5, 'Arabia': 5, 'E': 5, 'Democratic': 5, 'Kerry': 5, 'Apple': 5, 'Europe': 5, '##bble': 5, 'Space': 5, 'NASA': 5, 'European': 5, '##q': 5, 'Time': 5, '##J': 5, 'News': 5, 'R': 5, 'Al': 5, '##d': 5, 'Cheney': 5, '##le': 5, 'g': 5, '##lve': 5, '##2': 5, 'Fi': 5, 'Wall': 5, 'Street': 5, '##list': 5, 'BA': 5, '##AN': 5, 'TO': 5, '##X': 5, 'H': 5, '##last': 5, '##OL': 5, 'Palm': 5, 'In': 5, 'Chicago': 5, 'Sad': 5, '##U': 5, '##L': 5, 'Andrew': 5, 'Guard': 5, '##LA': 5, 'Tokyo': 5, 'Nik': 5, '##ke': 5, 'Motor': 5, 'Home': 5, 'USA': 4, '##l': 4, '##EC': 4, '##RT': 4, 'Web': 4, 'Korea': 4, 'He': 4, '##wl': 4, '##ett': 4, 'Packard': 4, 'Coast': 4, 'Lynn': 4, '##nick': 4, 'Chinese': 4, 'Ben': 4, '##sh': 4, 'Norwegian': 4, 'Mac': 4, '##cope': 4, 'Earth': 4, 'Britain': 4, 'State': 4, 'California': 4, 'Australian': 4, '##ter': 4, '##zilla': 4, '##ne': 4, '##on': 4, '##ity': 4, 'Z': 4, '##aw': 4, 'Cat': 4, 'Post': 4, '2': 4, 'Congress': 4, 'England': 4, '##our': 4, '##RI': 4, '##NE': 4, 'Los': 4, 'City': 4, 'Francisco': 4, 'Commission': 4, 'Jeffrey': 4, '##F': 4, '##R': 4, '##z': 4, 'Kent': 4, 'Kate': 4, '##rina': 4, 'Than': 4, '##is': 4, '##no': 4, 'Korean': 4, 'African': 4, 'Independence': 4, 'Jackson': 4, 'Singh': 4, 'Assam': 4, 'Hilton': 4, 'Toyota': 4, '##mp': 4, '##UM': 4, 'Depot': 4, 'Nations': 4, 'Ba': 3, 'Indian': 3, 'Ocean': 3, 'Network': 3, '##M': 3, 'Summer': 3, 'Block': 3, 'Win': 3, 'Republic': 3, 'Philippines': 3, 'and': 3, 'Sa': 3, '##pie': 3, '##nt': 3, 'Net': 3, '##k': 3, 'Sports': 3, 'Online': 3, '\\': 3, 'DVD': 3, 'Computer': 3, 'Oracle': 3, 'PC': 3, 'Texas': 3, 'Sun': 3, 'Service': 3, 'Ta': 3, 'North': 3, 'An': 3, 'Super': 3, 'County': 3, 'Taiwan': 3, 'Java': 3, 'De': 3, '##bian': 3, '##g': 3, 'al': 3, 'Hitler': 3, 'Hall': 3, 'George': 3, '##od': 3, '3': 3, 'Pack': 3, '##gs': 3, 'Associated': 3, 'Oregon': 3, '##NG ...

# %%
from pprint import pprint

pprint(positives)
# Out:
# Counter({'##uters': 57,
#          'Re': 56,
#          'S': 36,
#          '.': 34,
#          'U': 33,
#          'AP': 24,
#          '##K': 21,
#          'Olympic': 21,
#          'K': 20,
#          '##S': 19,
#          'of': 17,
#          'University': 17,
#          'Earth': 16,
#          'W': 16,
#          'Y': 15,
#          '-': 15,
#          '##OR': 14,
#          'American': 14,
#          'NASA': 14,
#          'Phelps': 13,
#          'NE': 12,
#          '##W': 12,
#          'A': 12,
#          'Michael': 12,
#          'Championship': 12,
#          '##o': 11,
#          'Inc': 11,
#          'Bush': 11,
#          'C': 11,
#          '##N': 10,
#          '##M': 10,
#          'Corp': 10,
#          'United': 10,
#          '##D': 10,
#          '##EN': 10,
#          'G': 9,
#          'N': 9,
#          'O': 9,
#          'P': 9,
#          '##d': 9,
#          'Java': 9,
#          'PGA': 9,
#          '##i': 8,
#          'New': 8,
#          'States': 8,
#          'F': 8,
#          '##A': 8,
#          'Pro': 8,
#          '##P': 8,
#          'John': 8,
#          '##co': 8,
#          '##sa': 7,
#          'National': 7,
#          'Health': 7,
#          'V': 7,
#          'Europe': 7,
#          'Per': 7,
#          '##sei': 7,
#          '##O': 7,
#          'Space': 7,
#          'Washington': 7,
#          'Iraq': 7,
#          'Microsoft': 7,
#          'J': 7,
#          'US': 7,
#          '##vez': 7,
#          'Japan': 7,
#          'Greece': 7,
#          '##is': 7,
#          'Ian': 7,
#          'Thorpe': 7,
#          '##e': 7,
#          'Vijay': 7,
#          'Singh': 7,
#          '##ar': 7,
#          'Venezuela': 7,
#          'T': 6,
#          'North': 6,
#          'X': 6,
#          'Open': 6,
#          'Ko': 6,
#          '3D': 6,
#          'Athens': 6,
#          'The': 6,
#          '##R': 6,
#          'Olympics': 6,
#          'Chandra': 6,
#          'E': 6,
#          'Do': 6,
#          '##ay': 6,
#          'AT': 6,
#          '##H': 6,
#          '##f': 6,
#          '##a': 6,
#          'Hugo': 6,
#          'Cha': 6,
#          'Di': 6,
#          'Google': 5,
#          'South': 5,
#          'Davis': 5,
#          'Asia': 5,
#          'B': 5,
#          'L': 5,
#          'British': 5,
#          'Station': 5,
#          "'": 5,
#          's': 5,
#          '##ran': 5,
#          'Hu': 5,
#          'M': 5,
#          'Ha': 5,
#          'Kerry': 5,
#          '##G': 5,
#          '##UN': 5,
#          '##B': 5,
#          '##LE': 5,
#          'Cut': 5,
#          'Wisconsin': 5,
#          'Central': 5,
#          '##Z': 5,
#          'War': 5,
#          '##y': 5,
#          'i': 5,
#          '##Y': 5,
#          'TO': 5,
#          '##U': 5,
#          'Japanese': 5,
#          'Pieter': 5,
#          'van': 5,
#          'den': 5,
#          'Ho': 5,
#          '##ogen': 5,
#          '##band': 5,
#          'Indians': 5,
#          'Twins': 5,
#          'Justin': 5,
#          'Leonard': 5,
#          'Hungarian': 5,
#          'Na': 5,
#          'Venezuelan': 5,
#          'Chris': 5,
#          'Ryder': 5,
#          'Cup': 5,
#          'Wall': 4,
#          'Street': 4,
#          'Asian': 4,
#          'International': 4,
#          'CA': 4,
#          '##k': 4,
#          '##ON': 4,
#          'He': 4,
#          '##wl': 4,
#          '##ett': 4,
#          'Packard': 4,
#          'Texas': 4,
#          '##s': 4,
#          'Russian': 4,
#          'America': 4,
#          '##ch': 4,
#          '##L': 4,
#          '##es': 4,
#          'Saturn': 4,
#          'the': 4,
#          'Saudi': 4,
#          'MS': 4,
#          '##FT': 4,
#          '##er': 4,
#          'Duke': 4,
#          'Z': 4,
#          'H': 4,
#          'Lu': 4,
#          '##nine': 4,
#          'Arizona': 4,
#          'St': 4,
#          '##c': 4,
#          '##let': 4,
#          'Keller': 4,
#          '##FP': 4,
#          'Cleveland': 4,
#          'Minnesota': 4,
#          '##ko': 4,
#          'League': 4,
#          'Chicago': 4,
#          '##histling': 4,
#          'Straits': 4,
#          'City': 4,
#          '##rman': 4,
#          'Jay': 4,
#          'Haas': 4,
#          'Grand': 4,
#          'Prix': 4,
#          'World': 4,
#          'Baghdad': 4,
#          '##ja': 4,
#          '##ah': 4,
#          '##OH': 4,
#          'Charley': 4,
#          'Willis': 4,
#          'Steve': 4,
#          '##al': 4,
#          'African': 3,
#          'Bay': 3,
#          'Thailand': 3,
#          '##EA': 3,
#          'Auto': 3,
#          '##des': 3,
#          'Service': 3,
#          'SEC': 3,
#          'Prize': 3,
#          'Linux': 3,
#          'Pacific': 3,
#          '##nos': 3,
#          '##bble': 3,
#          'Tel': 3,
#          '##cope': 3,
#          '##no': 3,
#          'So': 3,
#          'al': 3,
#          '##ma': 3,
#          'bin': 3,
#          'La': 3,
#          '##den': 3,
#          'API': 3,
#          'Northern': 3,
#          'Virginia': 3,
#          '##IS': 3,
#          '##m': 3,
#          'Florida': 3,
#          'Center': 3,
#          '##la': 3,
#          'Observatory': 3,
#          '##man': 3,
#          'Titan': 3,
#          'Reporter': 3,
#          'HP': 3,
#          'SA': 3,
#          '##l': 3,
#          'Apple': 3,
#          'In': 3,
#          'D': 3,
#          '##RO': 3,
#          'Games': 3,
#          'Motion': 3,
#          'DVD': 3,
#          'Studio': 3,
#          '3': 3,
#          'Louis': 3,
#          '##ol': 3,
#          'Team': 3,
#          'Los': 3,
#          'Angeles': 3,
#          'Press': 3,
#          'Tour': 3,
#          'French': 3,
#          'Jones': 3,
#          'Atlanta': 3,
#          'Braves': 3,
#          'Sc': 3,
#          '##AV': 3,
#          'San': 3,
#          'Francisco': 3,
#          'Andy': 3,
#          'Revolution': 3,
#          'Australia': 3,
#          'France': 3,
#          'Williams': 3,
#          'China': 3,
#          'Schumacher': 3,
#          'Afghanistan': 3,
#          'Afghan': 3,
#          'Lie': 3,
#          '##chtenstein': 3,
#          'Shi': 3,
#          '##ite': 3,
#          '##RA': 3,
#          'Corey': 3,
#          '##ski': 3,
#          'Donald': 3,
#          'Pan': 3,
#          'Riley': 3,
#          '##ee': 3,
#          '##AR': 3,
#          'Hal': 3,
#          'Mart': 3,
#          '##te': 3,
#          '##le': 2,
#          'Playboy': 2,
#          'Free': 2,
#          'Massachusetts': 2,
#          'Americans': 2,
#          'Chip': 2,
#          'Henry': 2,
#          'As': 2,
#          'Blues': 2,
#          'Philippines': 2,
#          '##pan': 2,
#          'Mu': 2,
#          '##MF': 2,
#          'Hong': 2,
#          'Kong': 2,
#          'Bangkok': 2,
#          '##t': 2,
#          'Systems': 2,
#          '##ner': 2,
#          'Sprint': 2,
#          'ST': 2,
#          '##ic': 2,
#          'Tech': 2,
#          'News': 2,
#          'Nobel': 2,
#          'Pen': 2,
#          '##cola': 2,
#          'Naval': 2,
#          'Air': 2,
#          'Columbia': 2,
#          'Valley': 2,
#          'Brazil': 2,
#          'Genesis': 2,
#          'Oregon': 2,
#          'State': 2,
#          'Anthony': 2,
#          'Ki': 2,
#          '##rin': 2,
#          '##ci': 2,
#          'DE': 2,
#          '##AD': 2,
#          'Mars': 2,
#          'Ty': 2,
#          're': 2,
#          'Baltimore': 2,
#          'Cass': 2,
#          '##ini': 2,
#          '##sca': 2,
#          'CNN': 2,
#          '##rb': 2,
#          'BA': 2,
#          '##ya': 2,
#          'Iraqi': 2,
#          'Syria': 2,
#          'Scotland': 2,
#          '##OS': 2,
#          '&': 2,
#          '##alo': 2,
#          '##w': 2,
#          'Bill': 2,
#          '##as': 2,
#          'Federal': 2,
#          'Senate': 2,
#          '##son': 2,
#          'Caribbean': 2,
#          '\\': 2,
#          'Me': 2,
#          'and': 2,
#          'At': 2,
#          '##mos': 2,
#          '##pheric': 2,
#          'Newcastle': 2,
#          'Apollo': 2,
#          '11': 2,
#          'Republic': 2,
#          'Lake': 2,
#          'for': 2,
#          '##an': 2,
#          '##SA': 2,
#          '##CO': 2,
#          'Canadian': 2,
#          'Ray': 2,
#          'ray': 2,
#          'Harry': 2,
#          'Bo': 2,
#          '##rt': 2,
#          '##gens': 2,
#          'Magazine': 2,
#          'European': 2,
#          '##r': 2,
#          'UC': 2,
#          'Ed': 2,
#          '##on': 2,
#          'Dell': 2,
#          '##T': 2,
#          'Blue': 2,
#          '##ter': 2,
#          '##ste': 2,
#          'Co': 2,
#          '##UR': 2,
#          '##I': 2,
#          '##AG': 2,
#          '##E': 2,
#          '##AM': 2,
#          'Cal': 2,
#          '##if': 2,
#          'MI': 2,
#          'VA': 2,
#          '##HA': 2,
#          'California': 2,
#          'Final': 2,
#          'HD': 2,
#          'Production': 2,
#          'Suite': 2,
#          '##C': 2,
#          'PC': 2,
#          'Power': 2,
#          '##cho': 2,
#          'Association': 2,
#          'AL': 2,
#          'Associated': 2,
#          '##lav': 2,
#          'I': 2,
#          '##dea': 2,
#          'Cardinals': 2,
#          'Canada': 2,
#          'Cubs': 2,
#          'Dodgers': 2,
#          'NFL': 2,
#          'Kansas': 2,
#          '##AN': 2,
#          '##n': 2,
#          'Renault': 2,
#          'F1': 2,
#          'Democratic': 2,
#          'George': 2,
#          'II': 2,
#          '##EM': 2,
#          'Lori': 2,
#          '##cking': 2,
#          'Mark': 2,
#          'Pope': 2,
#          'Spain': 2,
#          'Argentina': 2,
#          '##u': 2,
#          'Ferrari': 2,
#          'Cinema': 2,
#          '##ow': 2,
#          'Internet': 2,
#          'Hollywood': 2,
#          '##z': 2,
#          '##TA': 2,
#          'GO': 2,
#          '##RD': 2,
#          'Republican': 2,
#          '##J': 2,
#          '##AF': 2,
#          'Africa': 2,
#          'Brett': 2,
#          'Tom': 2,
#          'Philadelphia': 2,
#          'Phillies': 2,
#          'Randy': 2,
#          'Johnson': 2,
#          'Diamond': 2,
#          '##backs': 2,
#          'York': 2,
#          'Mets': 2,
#          '##ley': 2,
#          'Tennis': 2,
#          '##CA': 2,
#          'R': 2,
#          'Chinese': 2,
#          '##chen': 2,
#          'Lama': 2,
#          'Tibet': 2,
#          'Dallas': 2,
#          'Nation': 2,
#          '##wide': 2,
#          'Bills': 2,
#          'Fiji': 2,
#          '##g': 2,
#          '##iff': 2,
#          'Red': 2,
#          'Nico': 2,
#          'Bobby': 2,
#          'Fischer': 2,
#          '##oda': 2,
#          '##fo': 2,
#          '##ne': 2,
#          '##TT': 2,
#          'Stores': 2,
#          'Lowe': 2,
#          'Dow': 2,
#          '2004': 2,
#          'Princeton': 2,
#          'Research': 2,
#          'NC': 2,
#          'Stewart': 2,
#          '##ink': 2,
#          '##WA': 2,
#          'Science': 2,
#          'Cold': 2,
#          '##sted': 2,
#          'Polar': 2,
#          '##oid': 2,
#          'Chen': 2,
#          'Carly': 1,
#          'Group': 1,
#          'Trevor': 1,
#          '##lis': 1,
#          '##play': 1,
#          'Stein': 1,
#          'Detroit': 1,
#          '##tor': 1,
#          '##ga': 1,
#          'Pi': 1,
#          '##noy': 1,
#          'Lam': 1,
#          'Alley': 1,
#          'Clarence': 1,
#          'Henderson': 1,
#          'Manila': 1,
#          '##ddy': 1,
#          'Walters': 1,
#          'Chiang': 1,
#          'Mai': 1,
#          'Ph': 1,
#          '##uke': 1,
#          'Bali': 1,
#          'Indonesia': 1,
#          'Sense': 1,
#          'Place': 1,
#          'Singapore': 1,
#          'Computer': 1,
#          'Associates': 1,
#          'Un': 1,
#          '##ice': 1,
#          '##nter': 1,
#          'Buzz': 1,
#          'NHS': 1,
#          '##art': 1,
#          '##V': 1,
#          '##eri': 1,
#          '##zon': 1,
#          'Eli': 1,
#          'Bat': 1,
#          '##ista': 1,
#          'Instruments': 1,
#          'TX': 1,
#          '##ro': 1,
#          '##ele': 1,
#          '##ct': 1,
#          '##ronic': 1,
#          'PA': 1,
#          'Broad': 1,
#          '##com': 1,
#          'BR': 1,
#          '##CM': 1,
#          '##eb': 1,
#          'Jupiter': 1,
#          '##lut': 1,
#          'Moon': 1,
#          'Silicon': 1,
#          'Martha': 1,
#          'Vin': 1,
#          '##ey': 1,
#          '##ard': 1,
#          '##VE': 1,
#          'CO': 1,
#          'An': 1,
#          '##sar': 1,
#          '##aurus': 1,
#          '##x': 1,
#          'England': 1,
#          'Atlantic': 1,
#          '##qua': 1,
#          '##rium': 1,
#          'Alvin': 1,
#          'Gulf': 1,
#          'Mexico': 1,
#          'El': 1,
#          'Ni': 1,
#          'Voyager': 1,
#          'am': 1,
#          'Houston': 1,
#          'Michel': 1,
#          'Go': 1,
#          '##nd': 1,
#          '##ry': 1,
#          'Gap': 1,
#          'Eternal': 1,
#          'Sunshine': 1,
#          'Spot': 1,
#          '##less': 1,
#          'Mind': 1,
#          'IBM': 1,
#          '##ur': 1,
#          'Cloud': 1,
#          '##pe': 1,
#          'Qaeda': 1,
#          'Arabian': 1,
#          'Interior': 1,
#          'Ministry': 1,
#          '##hale': 1,
#          'Reagan': 1,
#          'Buddhism': 1,
#          'Buddhist': 1,
#          '##HD': 1,
#          'All': 1,
#          '##aw': 1,
#          'Coalition': 1,
#          'Provisional': 1,
#          'Authority': 1,
#          'We': 1,
#          '##apon': 1,
#          'Mass': 1,
#          'Des': 1,
#          '##truction': 1,
#          'Jordan': 1,
#          'Arabia': 1,
#          'Pakistan': 1,
#          'Iran': 1,
#          'Government': 1,
#          '##3': 1,
#          'BS': 1,
#          'Game': 1,
#          '##oy': 1,
#          'AN': 1,
#          '##GE': 1,
#          '##pra': 1,
#          'Yahoo': 1,
#          '##ung': 1,
#          'Chan': 1,
#          '##til': 1,
#          '##ly': 1,
#          'Fairfax': 1,
#          'Parents': 1,
#          'Without': 1,
#          'Partners': 1,
#          'Jason': 1,
#          'Same': 1,
#          'Deborah': 1,
#          'Major': 1,
#          'Trade': 1,
#          'Commission': 1,
#          'Timothy': 1,
#          '##ris': 1,
#          'Jessica': 1,
#          '##ler': 1,
#          'Russell': 1,
#          'Office': 1,
#          'Building': 1,
#          'Richard': 1,
#          'Virgin': 1,
#          'Global': 1,
#          'Fly': 1,
#          'Victorian': 1,
#          'Thom': 1,
#          'Parkinson': 1,
#          'Alzheimer': 1,
#          'UK': 1,
#          '21st': 1,
#          'Century': 1,
#          'Nature': 1,
#          'Tropical': 1,
#          'Rain': 1,
#          'Mission': 1,
#          'Ocean': 1,
#          'Administration': 1,
#          'NO': 1,
#          '##AA': 1,
#          'Madison': 1,
#          'Ice': 1,
#          'Age': 1,
#          'Dust': 1,
#          'Bowl': 1,
#          '##rap': 1,
#          'Wrath': 1,
#          '##OD': 1,
#          'Terra': 1,
#          'Rana': 1,
#          '##ni': 1,
#          'Sea': 1,
#          '##qui': 1,
#          '##lity': 1,
#          'Sudan': 1,
#          'Naked': 1,
#          'Ta': 1,
#          '##hoe': 1,
#          'Capt': 1,
#          '##ive': 1,
#          'Chi': 1,
#          '##mp': 1,
#          '##zee': 1,
#          'Care': 1,
#          'IS': 1,
#          'Progress': 1,
#          '15': 1,
#          '##da': 1,
#          '##IL': 1,
#          '##AC': 1,
#          '##LA': 1,
#          'Or': 1,
#          'Welles': 1,
#          'Worlds': 1,
#          '##pie': 1,
#          '##lberg': 1,
#          'Cruise': 1,
#          'Wells': 1,
#          '##tro': 1,
#          '##biology': 1,
#          'MA': 1,
#          'Hawaii': 1,
#          'Marshall': 1,
#          'Flight': 1,
#          'Sirius': 1,
#          'Agency': 1,
#          '##luster': 1,
#          'Jonathan': 1,
#          'Luna': 1,
#          'Planet': 1,
#          '##ary': 1,
#          'Laboratory': 1,
#          'Tucson': 1,
#          'Milk': 1,
#          'Way': 1,
#          'Jet': 1,
#          '##pulsion': 1,
#          'Lab': 1,
#          'Universal': 1,
#          'Time': 1,
#          'Kathleen': 1,
#          '##hen': 1,
#          'Amanda': 1,
#          'Gardner': 1,
#          '##MM': 1,
#          'Britain': 1,
#          '##els': 1,
#          'Austrian': 1,
#          'Proceedings': 1,
#          'Academy': 1,
#          'Sciences': 1,
#          'Oracle': 1,
#          '##isco': 1,
#          '##NE': 1,
#          'com': 1,
#          'Big': 1,
#          'Gateway': 1,
#          'Norte': 1,
#          'Indian': 1,
#          'Semi': 1,
#          '##conductor': 1,
#          '##11': 1,
#          '##0': 1,
#          'Portal': 1,
#          '##layer': 1,
#          'MP': 1,
#          'Edward': 1,
#          'Your': 1,
#          '##don': 1,
#          'Consortium': 1,
#          'IP': 1,
#          '##IP': 1,
#          'Sun': 1,
#          'Micro': 1,
#          '##sy': 1,
#          '##ms': 1,
#          '##lo': 1,
#          '##bby': 1,
#          '##fra': 1,
#          '##vio': 1,
#          'Web': 1,
#          'backed': 1,
#          'Send': 1,
#          'ID': 1,
#          '##MO': 1,
#          '##at': 1,
#          '##ue': 1,
#          'Liberty': 1,
#          '##LL': 1,
#          'Windows': 1,
#          'Sharp': 1,
#          'Newport': 1,
#          'Beach': 1,
#          '##cacia': 1,
#          'Media': 1,
#          'Technologies': 1,
#          'Who': 1,
#          'iTunes': 1,
#          'Music': 1,
#          'Store': 1,
#          '##ons': 1,
#          '##umi': 1,
#          '##ng': 1,
#          '##uit': 1,
#          '##ton': 1,
#          'Tokyo': 1,
#          '4': 1,
#          '0': 1,
#          'Guitar': 1,
#          'Player': 1,
#          'magazine': 1,
#          'Nashville': 1,
#          '##ara': 1,
#          '##ge': 1,
#          '##and': 1,
#          'Basketball': 1,
#          'Dream': 1,
#          'Travis': 1,
#          'Victor': 1,
#          'Martinez': 1,
#          'Kevin': 1,
#          'Hart': 1,
#          'Jon': 1,
#          'Busch': 1,
#          'Columbus': 1,
#          'Galaxy': 1,
#          'Crew': 1,
#          'Southern': 1,
#          'Trojan': 1,
#          'Italy': 1,
#          '##ia': 1,
#          'Penn': 1,
#          '##etta': 1,
#          'WTA': 1,
#          '##lar': 1,
#          '##uka': 1,
#          '##lov': 1,
#          'Czech': 1,
#          'Anastasia': 1,
#          'My': 1,
#          '##skin': 1,
#          '##per': 1,
#          'Julio': 1,
#          'Franco': 1,
#          'Greek': 1,
#          '##hin': 1,
#          '##ias': 1,
#          'Ole': 1,
#          '##rud': 1,
#          'Safe': 1,
#          'Field': 1,
#          'Yankees': 1,
#          '##ban': 1,
#          'Lo': 1,
#          '##ai': 1,
#          '##za': 1,
#          'Family': 1,
#          'Day': 1,
#          'Fen': 1,
#          'Wood': 1,
#          'Michigan': 1,
#          'Rich': 1,
#          '##ann': 1,
#          'MVP': 1,
#          'Raiders': 1,
#          'Oakland': 1,
#          '49ers': 1,
#          'WA': 1,
#          'RF': 1,
#          'Stadium': 1,
#          '##CE': 1,
#          '##PO': 1,
#          '##RT': 1,
#          'Sing': 1,
#          'Back': 1,
#          'Home': 1,
#          'Dec': 1,
#          '##ath': 1,
#          'Handicap': 1,
#          'Monmouth': 1,
#          'Park': 1,
#          'Champions': 1,
#          'Fernando': 1,
#          'USC': 1,
#          'Top': 1,
#          '25': 1,
#          'Australian': 1,
#          'Sally': 1,
#          '##mar': 1,
#          'Amber': 1,
#          'Hall': 1,
#          '##ida': 1,
#          'Korea': 1,
#          'Korean': 1,
#          'Sydney': 1,
#          'Edwards': 1,
#          'Democrat': 1,
#          'Shia': 1,
#          'Georgia': 1,
#          '##sse': 1,
#          '##tia': 1,
#          'Potter': 1,
#          'Row': 1,
#          '##ling': 1,
#          'OR': 1,
#          'Utah': 1,
#          '##DE': 1,
#          'Paul': 1,
#          'Mary': 1,
#          'Lou': 1,
#          '##rdes': 1,
#          '##yre': 1,
#          '##nees': 1,
#          'Roman': 1,
#          'Catholic': 1,
#          'Fantastic': 1,
#          'Food': 1,
#          'Challenge': 1,
#          'Arsenal': 1,
#          'English': 1,
#          'Everton': 1,
#          'Premier': 1,
#          'Rafael': 1,
#          '##dal': 1,
#          'ATP': 1,
#          'Jose': 1,
#          '##cas': 1,
#          '##us': 1,
#          '##ring': 1,
#          'III': 1,
#          'Amateur': 1,
#          'Yorker': 1,
#          'Wing': 1,
#          '##ed': 1,
#          'Foot': 1,
#          'Golf': 1,
#          'Club': 1,
#          'Lee': 1,
#          'Alexander': 1,
#          'Al': 1,
#          'Patrick': 1,
#          'Carter': 1,
#          'Les': 1,
#          '##age': 1,
#          'Nick': 1,
#          '##lana': 1,
#          '##gan': 1,
#          'Pa': 1,
#          'Gas': 1,
#          'Yao': 1,
#          'Ming': 1,
#          'Todd': 1,
#          'Hamilton': 1,
#          '##AB': 1,
#          'Alpine': 1,
#          'Allied': 1,
#          'Phi': 1,
#          '##sh': 1,
#          'Lions': 1,
#          'Gate': 1,
#          'Daniel': 1,
#          '##ron': 1,
#          '##ie': 1,
#          'Romania': 1,
#          '##pit': 1,
#          'Venus': 1,
#          'Melinda': 1,
#          '##zin': 1,
#          'Hungary': 1,
#          'Rod': 1,
#          '##dick': 1,
#          '##io': 1,
#          'Sa': 1,
#          '##retta': 1,
#          'Misty': 1,
#          'May': 1,
#          'Kerr': 1,
#          'Walsh': 1,
#          'Reserve': 1,
#          'Fed': 1,
#          'Alan': 1,
#          'Greens': 1,
#          'White': 1,
#          'House': 1,
#          '##ER': 1,
#          '##US': 1,
#          '##AL': 1,
#          'Israeli': 1,
#          'Jersey': 1,
#          'James': 1,
#          'Costa': 1,
#          'Rica': 1,
#          'Clint': 1,
#          'David': 1,
#          '##han': 1,
#          'Orioles': 1,
#          'Toronto': 1,
#          'Jays': 1,
#          '##rac': 1,
#          '##hs': 1,
#          '##el': 1,
#          'Adrian': 1,
#          'Belt': 1,
#          '##re': 1,
#          'Shawn': 1,
#          'Green': 1,
#          'Fin': 1,
#          'RBI': 1,
#          '##ov': 1,
#          '##ille': 1,
#          'Jenkins': 1,
#          'Boys': 1,
#          'Nationals': 1,
#          'Luis': 1,
#          'Castillo': 1,
#          'Dam': 1,
#          '##ion': 1,
#          'Mar': 1,
#          '##lins': 1,
#          'Milwaukee': 1,
#          'Brewers': 1,
#          'Haven': 1,
#          '##ums': 1,
#          '##feld': 1,
#          'Russia': 1,
#          '##les': 1,
#          'Toni': 1,
#          '##hl': 1,
#          '##ek': 1,
#          'Burn': 1,
#          'Metro': 1,
#          '##tars': 1,
#          'Jeffrey': 1,
#          'Steiner': 1,
#          'Fairchild': 1,
#          'Corporate': 1,
#          'Tiger': 1,
#          'Woods': 1,
#          'Tennessee': 1,
#          '##or': 1,
#          '##rell': 1,
#          'Brad': 1,
#          '##tt': 1,
#          'Price': 1,
#          'Charity': 1,
#          'Budapest': 1,
#          'Formula': 1,
#          'One': 1,
#          'Le': 1,
#          '##gg': 1,
#          'Mason': 1,
#          'Classic': 1,
#          'Robert': 1,
#          'Ken': 1,
#          '##drick': 1,
#          'Buffalo': 1,
#          'Denver': 1,
#          'Broncos': 1,
#          '##j': 1,
#          '##shi': 1,
#          'Ra': 1,
#          '##hm': 1,
#          'Be': 1,
#          'SH': 1,
#          'General': 1,
#          'Motors': 1,
#          'Cadillac': 1,
#          'Fred': 1,
#          'Funk': 1,
#          'Nicole': 1,
#          '##aid': 1,
#          '##ova': 1,
#          'Laura': 1,
#          'Gran': 1,
#          '##ville': 1,
#          'Vancouver': 1,
#          'Scott': 1,
#          'Role': 1,
#          'NL': 1,
#          'RBIs': 1,
#          '##hu': 1,
#          '##hol': 1,
#          'Sutton': 1,
#          'Iranian': 1,
#          'Giants': 1,
#          'Sox': 1,
#          'Arlington': 1,
#          'Lay': 1,
#          '##nce': 1,
#          'Nix': 1,
#          'Rangers': 1,
#          'Tampa': 1,
#          'Devil': 1,
#          'Africans': 1,
#          '##iv': 1,
#          '##iera': 1,
#          'Nazi': 1,
#          'Man': 1,
#          '##ino': 1,
#          '##bil': 1,
#          'Serbia': 1,
#          'Montenegro': 1,
#          'Ron': 1,
#          'Fellows': 1,
#          'NASCAR': 1,
#          'Watkins': 1,
#          'Glen': 1,
#          'Jenny': 1,
#          'Thompson': 1,
#          'Brendan': 1,
#          'Hansen': 1,
#          '##suke': 1,
#          'Kit': 1,
#          '##aj': 1,
#          '##ima': 1,
#          'Tony': 1,
#          '##ze': 1,
#          '##ved': 1,
#          'Croatian': 1,
#          'Fr': 1,
#          '##ano': 1,
#          'Vic': 1,
#          'Hans': 1,
#          'Adam': 1,
#          'Republicans': 1,
#          'Congress': 1,
#          'Darwin': 1,
#          'Lau': 1,
#          '##ryn': 1,
#          'Marion': 1,
#          'Spanish': 1,
#          'Carlos': 1,
#          'Mo': 1,
#          'Swedish': 1,
#          'Thomas': 1,
#          'En': 1,
#          '##q': 1,
#          '##vist': 1,
#          '##MT': 1,
#          'Southeast': 1,
#          'Flag': 1,
#          'Software': 1,
#          'Ltd': 1,
#          'Ohio': 1,
#          '##ys': 1,
#          '##rity': 1,
#          'Intel': 1,
#          'It': 1,
#          '##ani': 1,
#          '##um': 1,
#          '##NT': 1,
#          'Thomson': 1,
#          'l': 1,
#          'Cap': 1,
#          '##star': 1,
#          'Educational': 1,
#          'Testing': 1,
#          'Summer': 1,
#          'Paris': 1,
#          '##X': 1,
#          'Unix': 1,
#          'Alpha': 1,
#          '##erve': 1,
#          '##rs': 1,
#          'Brooklyn': 1,
#          '##vet': 1,
#          'Jarvis': 1,
#          'Ralph': 1,
#          'Good': 1,
#          '##ale': 1,
#          '##KE': 1,
#          'Bose': 1,
#          'Union': 1,
#          '##NC': 1,
#          '##IB': 1,
#          '##UT': 1,
#          '##BA': 1,
#          'Israel': 1,
#          'Baptist': 1,
#          'Testament': 1,
#          'CH': 1,
#          '##IC': 1,
#          '##mart': 1,
#          'Holdings': 1,
#          'Fast': 1,
#          'Forward': 1,
#          'Rob': 1,
#          '##ego': 1,
#          '##rar': 1,
#          'Post': 1,
#          'Over': 1,
#          '##land': 1,
#          '##orage': 1,
#          'Net': 1,
#          '##F': 1,
#          '##low': 1,
#          'Vicente': 1,
#          '##sco': 1,
#          '##bed': 1,
#          '##IN': 1,
#          '##CI': 1,
#          '##TI': 1,
#          'Western': 1,
#          'Nokia': 1,
#          'NY': 1,
#          '68': 1,
#          '##20': 1,
#          '##SM': 1,
#          'GP': 1,
#          '##RS': 1,
#          'Wyoming': 1,
#          'West': 1,
#          'Nile': 1,
#          'Black': 1,
#          '##erry': 1})

# %%
pprint(negatives)
# Out:
# Counter({'##uters': 124,
#          'Re': 121,
#          'S': 60,
#          '.': 58,
#          'U': 52,
#          'Inc': 45,
#          'AP': 40,
#          'Google': 38,
#          '##A': 37,
#          '##s': 33,
#          '##S': 32,
#          'N': 31,
#          'A': 30,
#          '##K': 28,
#          '##O': 27,
#          '##W': 26,
#          '-': 25,
#          '&': 25,
#          'NE': 24,
#          '##r': 24,
#          'Corp': 24,
#          'Microsoft': 24,
#          'Windows': 24,
#          '##i': 23,
#          'K': 23,
#          'Y': 22,
#          'O': 21,
#          '##P': 21,
#          '##OR': 20,
#          'L': 20,
#          'Iraq': 19,
#          'Florida': 19,
#          'Olympic': 19,
#          '##FP': 18,
#          '##RA': 18,
#          '##H': 17,
#          'J': 17,
#          'Internet': 17,
#          'Co': 17,
#          'Hugo': 17,
#          'Cha': 17,
#          '##vez': 17,
#          'US': 16,
#          'Sudan': 16,
#          'F': 16,
#          'New': 16,
#          'C': 16,
#          'Venezuelan': 16,
#          '##E': 15,
#          'I': 15,
#          'Charley': 15,
#          'San': 15,
#          '##G': 15,
#          'Venezuela': 15,
#          'South': 14,
#          'John': 14,
#          'B': 14,
#          'United': 14,
#          '##fu': 13,
#          '##C': 13,
#          '##n': 13,
#          '##D': 13,
#          '##T': 13,
#          'T': 12,
#          'P': 12,
#          'Dar': 12,
#          'The': 12,
#          'X': 12,
#          'MS': 12,
#          'CA': 12,
#          '##N': 11,
#          '##t': 11,
#          'Bush': 11,
#          "'": 11,
#          '##if': 11,
#          '##er': 11,
#          '##B': 11,
#          'HP': 11,
#          '##CA': 11,
#          'com': 10,
#          '##e': 10,
#          'National': 10,
#          'India': 10,
#          '##o': 10,
#          'M': 10,
#          '##ON': 10,
#          'SA': 10,
#          'GO': 10,
#          '##ay': 9,
#          'French': 9,
#          'Japan': 9,
#          'Playboy': 9,
#          'Canadian': 9,
#          'Mo': 9,
#          '##m': 9,
#          'l': 9,
#          'W': 9,
#          'Press': 9,
#          '##AL': 9,
#          'China': 9,
#          'Olympics': 9,
#          'Athens': 9,
#          'Na': 9,
#          '##I': 8,
#          'of': 8,
#          'American': 8,
#          'America': 8,
#          '##es': 8,
#          '##Y': 8,
#          '##UN': 8,
#          'e': 8,
#          'States': 8,
#          '##UR': 8,
#          '##IC': 8,
#          'Paul': 8,
#          '##f': 8,
#          'Iraqi': 8,
#          'Michael': 8,
#          'Games': 8,
#          '##NT': 8,
#          '##US': 8,
#          's': 8,
#          'IBM': 7,
#          'York': 7,
#          'G': 7,
#          'World': 7,
#          'British': 7,
#          'Australia': 7,
#          'Asia': 7,
#          'V': 7,
#          'Washington': 7,
#          'Linux': 7,
#          'Malaysia': 7,
#          'Ser': 7,
#          '##a': 7,
#          '##c': 7,
#          '##ou': 7,
#          'Greece': 7,
#          'Red': 7,
#          'Sox': 7,
#          '##EN': 7,
#          'Palestinian': 7,
#          'Israel': 7,
#          'Day': 7,
#          '##ja': 7,
#          'Afghanistan': 7,
#          'AT': 7,
#          'Lowe': 7,
#          '##mart': 7,
#          'Holding': 7,
#          'Saudi': 6,
#          'UK': 6,
#          'Si': 6,
#          'Gateway': 6,
#          'Russian': 6,
#          'Hu': 6,
#          'Tel': 6,
#          'University': 6,
#          '##eri': 6,
#          'Americans': 6,
#          'Shi': 6,
#          '##y': 6,
#          'St': 6,
#          'LA': 6,
#          'FCC': 6,
#          '"': 6,
#          'Cal': 6,
#          'Greek': 6,
#          'Ka': 6,
#          'Israeli': 6,
#          'All': 6,
#          'Rwanda': 6,
#          'Arab': 6,
#          '##ese': 6,
#          'Pope': 6,
#          '##TA': 6,
#          '##RD': 6,
#          '##la': 6,
#          'Puerto': 6,
#          'Rico': 6,
#          'Phelps': 6,
#          '##ER': 6,
#          'CH': 6,
#          '##AG': 6,
#          '##MR': 6,
#          'Dell': 5,
#          'Iran': 5,
#          'Japanese': 5,
#          'Arabia': 5,
#          'E': 5,
#          'Democratic': 5,
#          'Kerry': 5,
#          'Apple': 5,
#          'Europe': 5,
#          '##bble': 5,
#          'Space': 5,
#          'NASA': 5,
#          'European': 5,
#          '##q': 5,
#          'Time': 5,
#          '##J': 5,
#          'News': 5,
#          'R': 5,
#          'Al': 5,
#          '##d': 5,
#          'Cheney': 5,
#          '##le': 5,
#          'g': 5,
#          '##lve': 5,
#          '##2': 5,
#          'Fi': 5,
#          'Wall': 5,
#          'Street': 5,
#          '##list': 5,
#          'BA': 5,
#          '##AN': 5,
#          'TO': 5,
#          '##X': 5,
#          'H': 5,
#          '##last': 5,
#          '##OL': 5,
#          'Palm': 5,
#          'In': 5,
#          'Chicago': 5,
#          'Sad': 5,
#          '##U': 5,
#          '##L': 5,
#          'Andrew': 5,
#          'Guard': 5,
#          '##LA': 5,
#          'Tokyo': 5,
#          'Nik': 5,
#          '##ke': 5,
#          'Motor': 5,
#          'Home': 5,
#          'USA': 4,
#          '##l': 4,
#          '##EC': 4,
#          '##RT': 4,
#          'Web': 4,
#          'Korea': 4,
#          'He': 4,
#          '##wl': 4,
#          '##ett': 4,
#          'Packard': 4,
#          'Coast': 4,
#          'Lynn': 4,
#          '##nick': 4,
#          'Chinese': 4,
#          'Ben': 4,
#          '##sh': 4,
#          'Norwegian': 4,
#          'Mac': 4,
#          '##cope': 4,
#          'Earth': 4,
#          'Britain': 4,
#          'State': 4,
#          'California': 4,
#          'Australian': 4,
#          '##ter': 4,
#          '##zilla': 4,
#          '##ne': 4,
#          '##on': 4,
#          '##ity': 4,
#          'Z': 4,
#          '##aw': 4,
#          'Cat': 4,
#          'Post': 4,
#          '2': 4,
#          'Congress': 4,
#          'England': 4,
#          '##our': 4,
#          '##RI': 4,
#          '##NE': 4,
#          'Los': 4,
#          'City': 4,
#          'Francisco': 4,
#          'Commission': 4,
#          'Jeffrey': 4,
#          '##F': 4,
#          '##R': 4,
#          '##z': 4,
#          'Kent': 4,
#          'Kate': 4,
#          '##rina': 4,
#          'Than': 4,
#          '##is': 4,
#          '##no': 4,
#          'Korean': 4,
#          'African': 4,
#          'Independence': 4,
#          'Jackson': 4,
#          'Singh': 4,
#          'Assam': 4,
#          'Hilton': 4,
#          'Toyota': 4,
#          '##mp': 4,
#          '##UM': 4,
#          'Depot': 4,
#          'Nations': 4,
#          'Ba': 3,
#          'Indian': 3,
#          'Ocean': 3,
#          'Network': 3,
#          '##M': 3,
#          'Summer': 3,
#          'Block': 3,
#          'Win': 3,
#          'Republic': 3,
#          'Philippines': 3,
#          'and': 3,
#          'Sa': 3,
#          '##pie': 3,
#          '##nt': 3,
#          'Net': 3,
#          '##k': 3,
#          'Sports': 3,
#          'Online': 3,
#          '\\': 3,
#          'DVD': 3,
#          'Computer': 3,
#          'Oracle': 3,
#          'PC': 3,
#          'Texas': 3,
#          'Sun': 3,
#          'Service': 3,
#          'Ta': 3,
#          'North': 3,
#          'An': 3,
#          'Super': 3,
#          'County': 3,
#          'Taiwan': 3,
#          'Java': 3,
#          'De': 3,
#          '##bian': 3,
#          '##g': 3,
#          'al': 3,
#          'Hitler': 3,
#          'Hall': 3,
#          'George': 3,
#          '##od': 3,
#          '3': 3,
#          'Pack': 3,
#          '##gs': 3,
#          'Associated': 3,
#          'Oregon': 3,
#          '##NG': 3,
#          '##HA': 3,
#          '##pit': 3,
#          '##LL': 3,
#          'D': 3,
#          '##IE': 3,
#          '##OH': 3,
#          'Pa': 3,
#          '##ey': 3,
#          'AM': 3,
#          'ABC': 3,
#          'SP': 3,
#          '##erve': 3,
#          'HD': 3,
#          'Amazon': 3,
#          'Lee': 3,
#          'Yahoo': 3,
#          'MA': 3,
#          'Security': 3,
#          'SE': 3,
#          'Mike': 3,
#          'IP': 3,
#          '##lar': 3,
#          '##ia': 3,
#          'Roe': 3,
#          'Angeles': 3,
#          'Iranian': 3,
#          'Ara': 3,
#          'Mir': 3,
#          '##ma': 3,
#          'Championship': 3,
#          'La': 3,
#          'Bank': 3,
#          'Walter': 3,
#          'Ko': 3,
#          '4': 3,
#          'Seoul': 3,
#          '##ya': 3,
#          '##tad': 3,
#          'DE': 3,
#          '##ite': 3,
#          '##iff': 3,
#          'Davis': 3,
#          'Sprint': 3,
#          'Kobe': 3,
#          'Bryant': 3,
#          'Conference': 3,
#          '##DE': 3,
#          'France': 3,
#          'Africa': 3,
#          '##ster': 3,
#          'Be': 3,
#          '##GE': 3,
#          'Asian': 3,
#          '##pi': 3,
#          '##llar': 3,
#          'Power': 3,
#          'Kuala': 3,
#          'Lumpur': 3,
#          'Pro': 3,
#          '##oint': 3,
#          ',': 3,
#          'Warner': 3,
#          'Ltd': 3,
#          'Nepal': 3,
#          're': 3,
#          'Danny': 2,
#          'Riley': 2,
#          '##KA': 2,
#          'Yu': 2,
#          'WA': 2,
#          '##ING': 2,
#          'Chad': 2,
#          'West': 2,
#          'Ni': 2,
#          'Cambridge': 2,
#          'Sc': 2,
#          '##ge': 2,
#          'Central': 2,
#          'Square': 2,
#          'Art': 2,
#          '##isan': 2,
#          'Gary': 2,
#          'Global': 2,
#          'Russia': 2,
#          'the': 2,
#          'Old': 2,
#          'GM': 2,
#          '##man': 2,
#          'EA': 2,
#          'Mad': 2,
#          '##den': 2,
#          'NFL': 2,
#          '2005': 2,
#          '##nos': 2,
#          'Sean': 2,
#          'Ke': 2,
#          '##ef': 2,
#          'Aerospace': 2,
#          'Prize': 2,
#          'Mars': 2,
#          'Forest': 2,
#          'lunar': 2,
#          'Carolina': 2,
#          '##sar': 2,
#          'Nevada': 2,
#          'Agency': 2,
#          '##uin': 2,
#          'Southern': 2,
#          'Virginia': 2,
#          'Congo': 2,
#          'Mobile': 2,
#          'Jonathan': 2,
#          'Daemon': 2,
#          'Lo': 2,
#          '##4': 2,
#          '##AD': 2,
#          'CNN': 2,
#          'Omar': 2,
#          '##hr': 2,
#          'Qaeda': 2,
#          'Party': 2,
#          'Adolf': 2,
#          'Patrick': 2,
#          'Democrat': 2,
#          'Committee': 2,
#          'DOS': 2,
#          '##ob': 2,
#          'Indonesia': 2,
#          'Thailand': 2,
#          '##rar': 2,
#          '##amp': 2,
#          'Army': 2,
#          '##ry': 2,
#          '##io': 2,
#          'Wisconsin': 2,
#          '##IN': 2,
#          'SH': 2,
#          'Liberation': 2,
#          'Bai': 2,
#          '##kon': 2,
#          'Kazakhstan': 2,
#          'Health': 2,
#          '##RS': 2,
#          '##RE': 2,
#          '##TR': 2,
#          'Administration': 2,
#          '##NS': 2,
#          '##IT': 2,
#          '##cho': 2,
#          '##hart': 2,
#          'Real': 2,
#          '##ass': 2,
#          '##isco': 2,
#          '##al': 2,
#          '##ym': 2,
#          '##ce': 2,
#          'Eric': 2,
#          '##ham': 2,
#          'At': 2,
#          '##os': 2,
#          'Origin': 2,
#          'IT': 2,
#          '##NC': 2,
#          '##IS': 2,
#          '##CO': 2,
#          'UN': 2,
#          'Federal': 2,
#          'Communications': 2,
#          'Cinema': 2,
#          '##it': 2,
#          'PA': 2,
#          'Toy': 2,
#          'Us': 2,
#          '##OS': 2,
#          'MI': 2,
#          '##CH': 2,
#          '##EL': 2,
#          'Minnesota': 2,
#          '##rson': 2,
#          'Hopkins': 2,
#          'Min': 2,
#          '##ing': 2,
#          '##MP': 2,
#          '##han': 2,
#          'Engine': 2,
#          'Jose': 2,
#          'org': 2,
#          'Tech': 2,
#          '##hl': 2,
#          'Archive': 2,
#          'Server': 2,
#          'Sony': 2,
#          'Solutions': 2,
#          'Diego': 2,
#          '##eil': 2,
#          'Tiger': 2,
#          'PGA': 2,
#          '##rud': 2,
#          'Yankees': 2,
#          'Williamson': 2,
#          '##art': 2,
#          '##rent': 2,
#          '##sta': 2,
#          'International': 2,
#          '##AV': 2,
#          'Panthers': 2,
#          'Ma': 2,
#          '##LT': 2,
#          'Pi': 2,
#          'Maryland': 2,
#          'Ottawa': 2,
#          'Baltimore': 2,
#          'Orioles': 2,
#          'Georgian': 2,
#          '##sse': 2,
#          '##tia': 2,
#          'Kashmir': 2,
#          'Can': 2,
#          '##h': 2,
#          'Watson': 2,
#          '##HD': 2,
#          'Bosnia': 2,
#          '##AM': 2,
#          'Sharma': 2,
#          'Caribbean': 2,
#          '##TT': 2,
#          '##histling': 2,
#          'Straits': 2,
#          'Flyers': 2,
#          'Jeremy': 2,
#          'Philadelphia': 2,
#          '##quire': 2,
#          '##ND': 2,
#          'PR': 2,
#          'Martin': 2,
#          '##EG': 2,
#          'Nicky': 2,
#          'Todd': 2,
#          'Mei': 2,
#          'Las': 2,
#          'Vegas': 2,
#          'Wedding': 2,
#          'Chapel': 2,
#          'Clark': 2,
#          'Edwards': 2,
#          'Patriots': 2,
#          'Tim': 2,
#          'Duncan': 2,
#          'Allen': 2,
#          '##vers': 2,
#          '##as': 2,
#          'Atlanta': 2,
#          'Falcons': 2,
#          'Council': 2,
#          '##uru': 2,
#          '##ndi': 2,
#          'FA': 2,
#          'Vijay': 2,
#          'Mark': 2,
#          'AL': 2,
#          'Zealand': 2,
#          'Republican': 2,
#          '##da': 2,
#          'Jersey': 2,
#          'NY': 2,
#          '##MA': 2,
#          '##eg': 2,
#          'Lama': 2,
#          'Malaysian': 2,
#          'Sri': 2,
#          'Lanka': 2,
#          'Rana': 2,
#          '##ni': 2,
#          '##nger': 2,
#          'Bo': 2,
#          '##u': 2,
#          'Matt': 2,
#          'Kit': 2,
#          '##aj': 2,
#          '##ima': 2,
#          'Hansen': 2,
#          'Costa': 2,
#          'Pakistan': 2,
#          'Bangladesh': 2,
#          '##ys': 2,
#          ';': 2,
#          'SC': 2,
#          'Alpha': 2,
#          'GT': 2,
#          '##ri': 2,
#          'Fe': 2,
#          'RS': 2,
#          'Whole': 2,
#          '##ec': 2,
#          '##urity': 2,
#          'Content': 2,
#          '##uard': 2,
#          'Saddam': 2,
#          'Hussein': 2,
#          'Intel': 2,
#          '##sat': 2,
#          '##el': 2,
#          'Black': 2,
#          'Turkish': 2,
#          'Tea': 1,
#          '##raw': 1,
#          'Investment': 1,
#          'Company': 1,
#          'Institute': 1,
#          'Forbes': 1,
#          'Sociology': 1,
#          '##zi': 1,
#          'Non': 1,
#          '##urn': 1,
#          '##omo': 1,
#          '##gia': 1,
#          '##nto': 1,
#          '##ro': 1,
#          '##TO': 1,
#          'Shell': 1,
#          'Total': 1,
#          'Mauritius': 1,
#          '##MF': 1,
#          'UAE': 1,
#          '##tis': 1,
#          '##ala': 1,
#          'Rail': 1,
#          'Main': 1,
#          '##line': 1,
#          '##tro': 1,
#          '##ed': 1,
#          'Bill': 1,
#          'Gates': 1,
#          '##roo': 1,
#          'Steve': 1,
#          'Bailey': 1,
#          '##zzle': 1,
#          '##Z': 1,
#          'AK': 1,
#          '47': 1,
#          'Marlborough': 1,
#          'Crossing': 1,
#          'Kevin': 1,
#          'Rollins': 1,
#          'Fell': 1,
#          '##ini': 1,
#          'Tom': 1,
#          'Jerry': 1,
#          'General': 1,
#          'Motors': 1,
#          '##smo': 1,
#          '##bil': 1,
#          'Filipino': 1,
#          'Indians': 1,
#          'Thai': 1,
#          'Services': 1,
#          'Cap': 1,
#          '##mini': 1,
#          '##au': 1,
#          '##cher': 1,
#          '##in': 1,
#          'Netherlands': 1,
#          'Photo': 1,
#          '##op': 1,
#          'Far': 1,
#          'Daniel': 1,
#          'Te': 1,
#          '##rdi': 1,
#          'So': 1,
#          '##pra': 1,
#          'Osaka': 1,
#          'Ty': 1,
#          '##ran': 1,
#          '##aurus': 1,
#          'Rex': 1,
#          'Shakespeare': 1,
#          'Siberia': 1,
#          'Arm': 1,
#          '##adi': 1,
#          '##llo': 1,
#          'Me': 1,
#          '##qui': 1,
#          '##te': 1,
#          'Parker': 1,
#          'River': 1,
#          'Wildlife': 1,
#          'Refuge': 1,
#          'Argentine': 1,
#          'Venus': 1,
#          'Lake': 1,
#          '##hoe': 1,
#          'Han': 1,
#          '##oi': 1,
#          'Croatia': 1,
#          'Environmental': 1,
#          'Protection': 1,
#          'Kenny': 1,
#          '##nd': 1,
#          'Beaufort': 1,
#          'Sierra': 1,
#          'Swedish': 1,
#          'Atlantic': 1,
#          'sub': 1,
#          'Saharan': 1,
#          '##ug': 1,
#          '##tra': 1,
#          'mobile': 1,
#          '##zon': 1,
#          'ID': 1,
#          'Se': 1,
#          '##cure': 1,
#          'Science': 1,
#          'Corporation': 1,
#          'Register': 1,
#          'DC': 1,
#          'Defence': 1,
#          'Force': 1,
#          'Joint': 1,
#          'Strike': 1,
#          'Fighter': 1,
#          'Bright': 1,
#          '##CP': 1,
#          'Moore': 1,
#          '##or': 1,
#          '##ld': 1,
#          '##TP': 1,
#          '##ons': 1,
#          '##th': 1,
#          'King': 1,
#          '##ah': 1,
#          '##hab': 1,
#          '##an': 1,
#          'Faces': 1,
#          'Move': 1,
#          'Senate': 1,
#          'Leah': 1,
#          'Judiciary': 1,
#          '##ib': 1,
#          '##urt': 1,
#          'III': 1,
#          '##ny': 1,
#          'Budget': 1,
#          'Office': 1,
#          'Doom': 1,
#          'Of': 1,
#          '##com': 1,
#          'PlayStation': 1,
#          'Northumberland': 1,
#          '##woman': 1,
#          '##FT': 1,
#          '##rda': 1,
#          'Rob': 1,
#          '##ego': 1,
#          '##do': 1,
#          'Leslie': 1,
#          'Walker': 1,
#          'Um': 1,
#          '##esh': 1,
#          'Patel': 1,
#          '##ker': 1,
#          '130': 1,
#          '##V': 1,
#          'Jacob': 1,
#          '##oh': 1,
#          '##ls': 1,
#          '##tadt': 1,
#          'c': 1,
#          'Columbia': 1,
#          'Worcestershire': 1,
#          'Alaska': 1,
#          'Max': 1,
#          'Plan': 1,
#          '##ck': 1,
#          'Society': 1,
#          'Madison': 1,
#          '##lis': 1,
#          'Voyager': 1,
#          '1': 1,
#          'Deck': 1,
#          '##chair': 1,
#          'Olympia': 1,
#          'SR': 1,
#          '##VA': 1,
#          '##SA': 1,
#          'Shen': 1,
#          '##zhou': 1,
#          '5': 1,
#          'Daily': 1,
#          'Exploration': 1,
#          'Luna': 1,
#          'Progress': 1,
#          '50': 1,
#          '##zer': 1,
#          'Harvard': 1,
#          'Heart': 1,
#          'Letter': 1,
#          'Amanda': 1,
#          'Gardner': 1,
#          'Reporter': 1,
#          '2004': 1,
#          '##ST': 1,
#          '##VI': 1,
#          'Kennedy': 1,
#          'Park': 1,
#          'Food': 1,
#          'Drug': 1,
#          'Lester': 1,
#          'Crawford': 1,
#          'Nelson': 1,
#          '##DA': 1,
#          'Massachusetts': 1,
#          'ME': 1,
#          'Mexican': 1,
#          'Laura': 1,
#          'Dam': 1,
#          '##aris': 1,
#          'IRA': 1,
#          '##ins': 1,
#          'Knowledge': 1,
#          'Len': 1,
#          '##ovo': 1,
#          'Start': 1,
#          'Edition': 1,
#          'Charles': 1,
#          'Cooper': 1,
#          '##tel': 1,
#          '##lini': 1,
#          'Air': 1,
#          '##ort': 1,
#          'Express': 1,
#          'Via': 1,
#          '##gra': 1,
#          '##her': 1,
#          'El': 1,
#          '##gam': 1,
#          '##gle': 1,
#          'Baby': 1,
#          'Bells': 1,
#          'Motion': 1,
#          'Department': 1,
#          'Energy': 1,
#          '##amo': 1,
#          'Laboratory': 1,
#          'Circuit': 1,
#          '##IB': 1,
#          'Markets': 1,
#          '##EA': 1,
#          'Systems': 1,
#          'Craig': 1,
#          'Advanced': 1,
#          'Micro': 1,
#          'Devi': 1,
#          '##ces': 1,
#          'Goldman': 1,
#          'Sachs': 1,
#          '##IX': 1,
#          '##quito': 1,
#          '##TV': 1,
#          'Wonder': 1,
#          '##buster': 1,
#          '##ow': 1,
#          'Movie': 1,
#          '##ick': 1,
#          '##ets': 1,
#          'Spanish': 1,
#          '##tu': 1,
#          'Gold': 1,
#          '##TE': 1,
#          'Margaret': 1,
#          '##KE': 1,
#          'Hollywood': 1,
#          '##ular': 1,
#          'Wireless': 1,
#          'Virgin': 1,
#          'Exchange': 1,
#          '##re': 1,
#          'Search': 1,
#          '##rate': 1,
#          '##gies': 1,
#          'Ad': 1,
#          'Trade': 1,
#          'Association': 1,
#          'Terra': 1,
#          '##cos': 1,
#          'Shop': 1,
#          'Forrest': 1,
#          'Interview': 1,
#          'go': 1,
#          'Index': 1,
#          'Database': 1,
#          '##irt': 1,
#          'Mercury': 1,
#          'Brewster': 1,
#          'Control': 1,
#          '2003': 1,
#          '##ET': 1,
#          '##nes': 1,
#          '##ot': 1,
#          '##tics': 1,
#          'Group': 1,
#          'Mario': 1,
#          '##der': 1,
#          'Adam': 1,
#          '##reis': 1,
#          'Stanford': 1,
#          'Flow': 1,
#          'OS': 1,
#          '##ily': 1,
#          'Pen': 1,
#          'Cincinnati': 1,
#          'Reds': 1,
#          'Padres': 1,
#          'NL': 1,
#          '##LE': 1,
#          'Woods': 1,
#          '##ash': 1,
#          'Cola': 1,
#          '##nder': 1,
#          'Marion': 1,
#          'Jones': 1,
#          'Ole': 1,
#          'Seattle': 1,
#          'Mariners': 1,
#          'League': 1,
#          'Alex': 1,
#          'Rodriguez': 1,
#          'Boston': 1,
#          'Scott': 1,
#          'Curtis': 1,
#          'Les': 1,
#          '##kan': 1,
#          '##ic': 1,
#          'Citizens': 1,
#          'Cara': 1,
#          '##van': 1,
#          'Rae': 1,
#          'Family': 1,
#          '##MCA': 1,
#          'White': 1,
#          'Channel': 1,
#          '38': 1,
#          'Stuart': 1,
#          '##by': 1,
#          'Fernando': 1,
#          '##ar': 1,
#          'Pat': 1,
#          '##ond': 1,
#          'Redskins': 1,
#          '##say': 1,
#          '##rea': 1,
#          'Met': 1,
#          '##shi': 1,
#          '##ska': 1,
#          'Wimbledon': 1,
#          'Mali': 1,
#          '##va': 1,
#          '##IM': 1,
#          'East': 1,
#          '##lic': 1,
#          'Race': 1,
#          'Course': 1,
#          'Brand': 1,
#          'Stakes': 1,
#          '##onte': 1,
#          '##not': 1,
#          '##ynx': 1,
#          'Maria': 1,
#          '##well': 1,
#          'Was': 1,
#          'Missouri': 1,
#          'Lou': 1,
#          '##rdes': 1,
#          'Roman': 1,
#          'Catholics': 1,
#          '##mail': 1,
#          'Santa': 1,
#          'Barbara': 1,
#          'Nat': 1,
#          'High': 1,
#          'Ho': 1,
#          '##born': 1,
#          'London': 1,
#          '##AB': 1,
#          '##hdi': 1,
#          'Baghdad': 1,
#          'SAS': 1,
#          '##BO': 1,
#          '##VO': 1,
#          'Herzegovina': 1,
#          'NATO': 1,
#          'Jin': 1,
#          '##lor': 1,
#          '##idian': 1,
#          'Man': 1,
#          '##mo': 1,
#          'Front': 1,
#          'As': 1,
#          '##om': 1,
#          'Police': 1,
#          '##hage': 1,
#          'Muslim': 1,
#          '##ites': 1,
#          'Marines': 1,
#          '98': 1,
#          'Kathleen': 1,
#          'Willem': 1,
#          '##kker': 1,
#          'Dutch': 1,
#          '##RC': 1,
#          '##VE': 1,
#          '##RL': 1,
#          '##cs': 1,
#          '##ik': 1,
#          'Rangers': 1,
#          'ERA': 1,
#          '##WA': 1,
#          'Canada': 1,
#          'House': 1,
#          'CIA': 1,
#          'Reserve': 1,
#          '##ED': 1,
#          '##DI': 1,
#          '##ding': 1,
#          'Page': 1,
#          'Baba': 1,
#          '##ano': 1,
#          '##ush': 1,
#          '##bo': 1,
#          '##uli': 1,
#          'Gene': 1,
#          '##tic': 1,
#          'Savings': 1,
#          '##lone': 1,
#          'Nightmare': 1,
#          'Team': 1,
#          'Palestinians': 1,
#          'CP': 1,
#          '##ca': 1,
#          '##dian': 1,
#          'Nova': 1,
#          'Scotia': 1,
#          'RAM': 1,
#          '##lls': 1,
#          'Daryl': 1,
#          '##land': 1,
#          'Cuba': 1,
#          'Italy': 1,
#          '##vio': 1,
#          '##rl': 1,
#          '##us': 1,
#          '##con': 1,
#          'Rome': 1,
#          'Iowa': 1,
#          'Eagles': 1,
#          'Bruce': 1,
#          'Perry': 1,
#          'Alien': 1,
#          'vs': 1,
#          'Fred': 1,
#          '##ley': 1,
#          '49ers': 1,
#          'Tu': 1,
#          '##ts': 1,
#          '##les': 1,
#          'Randy': 1,
#          'Johnson': 1,
#          'Arizona': 1,
#          'Diamond': 1,
#          '##backs': 1,
#          'Mets': 1,
#          'Kosovo': 1,
#          'Serbian': 1,
#          'Richard': 1,
#          '##ahl': 1,
#          'Justin': 1,
#          'Leonard': 1,
#          'Jr': 1,
#          'Ian': 1,
#          'Thorpe': 1,
#          'Dunedin': 1,
#          'Ralph': 1,
#          'Fr': 1,
#          '##ied': 1,
#          '##gen': 1,
#          'Convention': 1,
#          'Kern': 1,
#          'ST': 1,
#          'GE': 1,
#          '##rena': 1,
#          'Earl': 1,
#          'CBS': 1,
#          'Democrats': 1,
#          'Auto': 1,
#          'Workers': 1,
#          '##ME': 1,
#          'Southeast': 1,
#          '##IP': 1,
#          '##EI': 1,
#          'Mart': 1,
#          'People': 1,
#          'GMA': 1,
#          'Manila': 1,
#          'Tibet': 1,
#          'Pan': 1,
#          '##chen': 1,
#          '##hasa': 1,
#          'Him': 1,
#          '##alaya': 1,
#          'Buddha': 1,
#          'Dal': 1,
#          '##ai': 1,
#          'Hat': 1,
#          'Mal': 1,
#          '##dives': 1,
#          'Tamil': 1,
#          'Norway': 1,
#          'Kabul': 1,
#          'GPS': 1,
#          '##hibit': 1,
#          '##ex': 1,
#          'Manuel': 1,
#          '##lina': 1,
#          'Rolling': 1,
#          'Stones': 1,
#          'Orlando': 1,
#          '##ab': 1,
#          '##rera': 1,
#          'Chris': 1,
#          'Louis': 1,
#          'Blues': 1,
#          'Cup': 1,
#          'Hockey': 1,
#          'Jay': 1,
#          '##w': 1,
#          '##mee': 1,
#          'Light': 1,
#          'James': 1,
#          '##ree': 1,
#          '##vey': 1,
#          '##book': 1,
#          '##ers': 1,
#          'it': 1,
#          'Mary': 1,
#          'Western': 1,
#          'Byzantine': 1,
#          '##suke': 1,
#          'Brendan': 1,
#          'Lisa': 1,
#          'Fernandez': 1,
#          'Andre': 1,
#          'Bert': 1,
#          'Per': 1,
#          '##ister': 1,
#          'Boxing': 1,
#          'Georgia': 1,
#          'Vision': 1,
#          'Multi': 1,
#          '##media': 1,
#          'Samsung': 1,
#          'Carr': 1,
#          '##quer': 1,
#          'Elections': 1,
#          '##sir': 1,
#          '##iya': 1,
#          '##ential': 1,
#          '##LC': 1,
#          'Peter': 1,
#          'Falcon': 1,
#          '##watch': 1,
#          'CB': 1,
#          'ON': 1,
#          '##atch': 1,
#          'Bear': 1,
#          'McLean': 1,
#          'Transportation': 1,
#          'Airbus': 1,
#          'Boeing': 1,
#          'Alzheimer': 1,
#          'Declan': 1,
#          '##ull': 1,
#          '##agh': 1,
#          'Club': 1,
#          'Fed': 1,
#          'Islamic': 1,
#          'Ministry': 1,
#          '##OW': 1,
#          'Airways': 1,
#          'Holiday': 1,
#          'Kentucky': 1,
#          '##co': 1,
#          '##yman': 1,
#          '##tec': 1,
#          'Angola': 1,
#          'Serbia': 1,
#          'Montenegro': 1,
#          '##rito': 1,
#          '##cc': 1,
#          '##ev': 1,
#          'Unix': 1,
#          '##rity': 1,
#          '900': 1,
#          '##0': 1,
#          '##state': 1,
#          'Hungarian': 1,
#          'Lebanese': 1,
#          'Indonesian': 1,
#          'Mega': 1,
#          '##wati': 1,
#          'Su': 1,
#          '##kar': 1,
#          '##put': 1,
#          '##AS': 1,
#          '##CU': 1,
#          'Syrian': 1,
#          'Life': 1,
#          'Hospital': 1,
#          'LP': 1,
#          'Province': 1,
#          'Healthcare': 1,
#          'Czech': 1,
#          'Pittsburgh': 1,
#          'Penguins': 1,
#          'Ivan': 1,
#          '##link': 1,
#          'RF': 1,
#          '##ID': 1,
#          'Where': 1,
#          '##Net': 1,
#          'Suite': 1,
#          'Ch': 1,
#          '##ech': 1,
#          '##nya': 1,
#          '##eds': 1,
#          'Benjamin': 1,
#          'Mon': 1,
#          '##eta': 1,
#          'Fund': 1,
#          'Communist': 1,
#          'Pacific': 1,
#          'Tor': 1,
#          'Tribune': 1,
#          '##cha': 1,
#          '##iko': 1,
#          '##vsky': 1,
#          '##RO': 1,
#          'Ontario': 1,
#          'Dalton': 1,
#          '##ty': 1,
#          'Times': 1,
#          'Keith': 1,
#          'Jack': 1,
#          '##de': 1,
#          'Afghan': 1,
#          'Mu': 1,
#          'Munich': 1,
#          '##tley': 1,
#          'Fool': 1,
#          'Dai': 1,
#          '##mler': 1,
#          '##ler': 1,
#          '##yun': 1,
#          '##dai': 1,
#          'Baptist': 1,
#          '##ron': 1,
#          'Days': 1,
#          '##ko': 1,
#          'Bertrand': 1,
#          '##tat': 1,
#          'Lithuania': 1,
#          '##ids': 1,
#          'Entertainment': 1,
#          '##fe': 1,
#          '##AT': 1,
#          'Porsche': 1,
#          'Portuguese': 1,
#          'Union': 1,
#          '11': 1,
#          'Muslims': 1,
#          '##AF': 1,
#          '##mond': 1,
#          '##v': 1,
#          'Newport': 1,
#          'Beach': 1,
#          'Q': 1,
#          '##x': 1,
#          'Explorer': 1,
#          '##oda': 1,
#          '##fo': 1,
#          'Do': 1,
#          'Has': 1,
#          '##bro': 1,
#          'Le': 1,
#          '##hman': 1,
#          'Brothers': 1,
#          '##base': 1,
#          '##uild': 1,
#          '10': 1,
#          'Ada': 1,
#          '##pt': 1,
#          '##ive': 1,
#          'Enterprise': 1,
#          'Lakers': 1,
#          'Il': 1,
#          '##hawks': 1,
#          'Bryan': 1,
#          'Chan': 1,
#          'Taylor': 1,
#          'TV': 1,
#          '##erry': 1,
#          'Works': 1,
#          'Face': 1,
#          '##ime': 1,
#          '##ju': 1,
#          'Bradley': 1,
#          'Ogden': 1})

# %%
negatives.most_common(20)
# Out:
# [('##uters', 124),
#  ('Re', 121),
#  ('S', 60),
#  ('.', 58),
#  ('U', 52),
#  ('Inc', 45),
#  ('AP', 40),
#  ('Google', 38),
#  ('##A', 37),
#  ('##s', 33),
#  ('##S', 32),
#  ('N', 31),
#  ('A', 30),
#  ('##K', 28),
#  ('##O', 27),
#  ('##W', 26),
#  ('-', 25),
#  ('&', 25),
#  ('NE', 24),
#  ('##r', 24)]

# %%
print(sentiment_classifier("Donald Trump is the worst president of the United States"))
print(sentiment_classifier("Donald Trump is the best president of the United States"))
print(sentiment_classifier("Donald Trump is not the worst president of the United States"))
print(sentiment_classifier("Donald Trump is not the best president of the United States"))
print(sentiment_classifier("Donald Trump isn't the worst president of the United States"))
print(sentiment_classifier("Donald Trump isn't the best president of the United States"))
# Out:
# [{'word': 'Donald', 'score': 0.9988574385643005, 'entity': 'I-PER'}, {'word': 'Trump', 'score': 0.9992254972457886, 'entity': 'I-PER'}, {'word': 'Spain', 'score': 0.9997214674949646, 'entity': 'I-LOC'}]

# %%
from collections import defaultdict

facts = defaultdict(list)

for text in tqdm(news["text"][-1000:]):
    doc = nlp(text)
    for sentence in doc.sents:
        who, action, what, whom = None, None, None, None
        for token in sentence:
            if action == None and token.dep_ == "ROOT":
                action = token.text
            elif who == None and token.dep_ == "nsubj":
                who = token.text
            elif what == None and token.dep_ == "dobj" or token.dep_ == "attr" or token.dep_ == "ccomp":
                what = token.text
            elif whom == None and token.dep_ == "iobj":
                whom = token.text

    if who:
        facts[who.lower()].append((who, action, what, whom, sentence))
# Out:
# HBox(children=(IntProgress(value=0, max=1000), HTML(value='')))

# %%
def search_facts_about(who: str):
    return facts[who.lower()]

# %%
search_facts_about("Bush")
# Out:
# [('Bush',
#   'signs',
#   'overhaul',
#   None,
#   President George Bush signs into law the country's most radical overhaul of its intelligence agencies in nearly 60 years.),
#  ('Bush',
#   'signed',
#   'overhaul',
#   None,
#   AP - President Bush on Friday signed the largest overhaul of U.S. intelligence-gathering in a half century, aiming to transform a system designed for Cold War threats so it can deal effectively with the post-Sept. 11 scourge of terrorism.),
#  ('Bush',
#   'creating',
#   'committee',
#   None,
#   AP - President Bush is creating a White House committee to oversee the nation's ocean policies, with plans to improve research, manage fisheries better and regulate pollution caused by boats.),
#  ('Bush',
#   'ordered',
#   'creation',
#   None,
#   In response to a gloomy assessment of the state of the nation's coastal waters, President Bush ordered the creation of a new federal panel to coordinate oceanic policy.)]
